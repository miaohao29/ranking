# %%
import numpy as np
import pandas as pd

# %%
a=[]
with (open(r"C:\Users\rk\Desktop\N&S3.txt",encoding='utf-8')) as f:
    for li in f:
        a.append(li)

# %%
b=[]
for item in a:
    item=item.split('\t')
    b.append(item)

# %%
for item in b:
    if len(item)!=70:
        print(len(item),item)
# Out:
# 69 ['上海中医药大学', '\ufeffPT', 'AU', 'BA', 'BE', 'GP', 'AF', 'BF', 'CA', 'TI', 'SO', 'SE', 'BS', 'LA', 'DT', 'CT', 'CY', 'CL', 'SP', 'HO', 'DE', 'ID', 'AB', 'C1', 'RP', 'EM', 'RI', 'OI', 'FU', 'FX', 'CR', 'NR', 'TC', 'Z9', 'U1', 'U2', 'PU', 'PI', 'PA', 'SN', 'EI', 'BN', 'J9', 'JI', 'PD', 'PY', 'VL', 'IS', 'PN', 'SU', 'SI', 'MA', 'BP', 'EP', 'AR', 'DI', 'D2', 'EA', 'EY', 'PG', 'WC', 'SC', 'GA', 'UT', 'PM', 'OA', 'HC', 'HP', 'DA\n']

# %%
b[0].append(b[0].pop()[:2])
b[0].append('\n')

# %%
len(b[0])
# Out:
# 70

# %%
b[0]
# Out:
# ['上海中医药大学',
#  '\ufeffPT',
#  'AU',
#  'BA',
#  'BE',
#  'GP',
#  'AF',
#  'BF',
#  'CA',
#  'TI',
#  'SO',
#  'SE',
#  'BS',
#  'LA',
#  'DT',
#  'CT',
#  'CY',
#  'CL',
#  'SP',
#  'HO',
#  'DE',
#  'ID',
#  'AB',
#  'C1',
#  'RP',
#  'EM',
#  'RI',
#  'OI',
#  'FU',
#  'FX',
#  'CR',
#  'NR',
#  'TC',
#  'Z9',
#  'U1',
#  'U2',
#  'PU',
#  'PI',
#  'PA',
#  'SN',
#  'EI',
#  'BN',
#  'J9',
#  'JI',
#  'PD',
#  'PY',
#  'VL',
#  'IS',
#  'PN',
#  'SU',
#  'SI',
#  'MA',
#  'BP',
#  'EP',
#  'AR',
#  'DI',
#  'D2',
#  'EA',
#  'EY',
#  'PG',
#  'WC',
#  'SC',
#  'GA',
#  'UT',
#  'PM',
#  'OA',
#  'HC',
#  'HP',
#  'DA',
#  '\n']

# %%
b[1]
# Out:
# ['上海中医药大学',
#  'J',
#  'Jia, W; Fan, TP; Wang, XN; Xie, GX',
#  '',
#  '',
#  '',
#  'Jia, Wei; Fan, Tai-ping; Wang, Xiaoning; Xie, Guoxiang',
#  '',
#  '',
#  'The polypharmacokinetics of herbal medicines',
#  'SCIENCE',
#  '',
#  '',
#  'English',
#  'Editorial Material',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'STRATEGY; MICROBIOTA; LICORICE; RATS; TEA',
#  '',
#  '[Jia, Wei] Shanghai Jiao Tong Univ, Affiliated Peoples Hosp 6, Dept Endocrinol & Metab, Shanghai Key Lab Diabet Mellitus, Shanghai 200030, Peoples R China; [Jia, Wei] Shanghai Jiao Tong Univ, Affiliated Peoples Hosp 6, Dept Endocrinol & Metab, Ctr Translat Med, Shanghai 200030, Peoples R China; [Jia, Wei; Xie, Guoxiang] Univ Hawaii, Ctr Canc, Honolulu, HI 96822 USA; [Jia, Wei; Wang, Xiaoning] Shanghai Univ Tradit Chinese Med, E Inst, Shanghai Municipal Educ Comm, Shanghai, Peoples R China; [Fan, Tai-ping] Univ Cambridge, Dept Pharmacol, Angiogenesis & Tradit Chinese Med Lab, Cambridge CB2 1QJ, England',
# ...

# %%
b[1][3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-deb2391673a7> in <module>()
# ----> 1 b[1][3]
#
# NameError: name 'b' is not defined

# %%
'Article' in b[1]
# Out:
# False

# %%
b[0][9]
# Out:
# 'TI'

# %%
b[2]
# Out:
# ['上海交通大学',
#  'J',
#  'Shen, Y; Li, YD; Wo, HL; Li, YS; Shen, SD; Pan, BY; Wang, QS; Walker, HC; Steffens, P; Boehm, M; Hao, YQ; Quintero-Castro, DL; Harriger, LW; Frontzek, MD; Hao, LJ; Meng, SQ; Zhang, QM; Chen, G; Zhao, J',
#  '',
#  '',
#  '',
#  'Shen, Yao; Li, Yao-Dong; Wo, Hongliang; Li, Yuesheng; Shen, Shoudong; Pan, Bingying; Wang, Qisi; Walker, H. C.; Steffens, P.; Boehm, M.; Hao, Yiqing; Quintero-Castro, D. L.; Harriger, L. W.; Frontzek, M. D.; Hao, Lijie; Meng, Siqin; Zhang, Qingming; Chen, Gang; Zhao, Jun',
#  '',
#  '',
#  'Evidence for a spinon Fermi surface in a triangular-lattice quantum-spin-liquid candidate',
#  'NATURE',
#  '',
#  '',
#  'English',
#  'Article',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'VALENCE-BOND STATE; KAGOME-LATTICE; GROUND-STATE; SUPERCONDUCTIVITY; ANTIFERROMAGNET; EXCITATIONS; TOPOLOGY; PHYSICS',
# ...

# %%
'Article' in b[2]
# Out:
# True

# %%
b[2]
# Out:
# ['上海交通大学',
#  'J',
#  'Shen, Y; Li, YD; Wo, HL; Li, YS; Shen, SD; Pan, BY; Wang, QS; Walker, HC; Steffens, P; Boehm, M; Hao, YQ; Quintero-Castro, DL; Harriger, LW; Frontzek, MD; Hao, LJ; Meng, SQ; Zhang, QM; Chen, G; Zhao, J',
#  '',
#  '',
#  '',
#  'Shen, Yao; Li, Yao-Dong; Wo, Hongliang; Li, Yuesheng; Shen, Shoudong; Pan, Bingying; Wang, Qisi; Walker, H. C.; Steffens, P.; Boehm, M.; Hao, Yiqing; Quintero-Castro, D. L.; Harriger, L. W.; Frontzek, M. D.; Hao, Lijie; Meng, Siqin; Zhang, Qingming; Chen, Gang; Zhao, Jun',
#  '',
#  '',
#  'Evidence for a spinon Fermi surface in a triangular-lattice quantum-spin-liquid candidate',
#  'NATURE',
#  '',
#  '',
#  'English',
#  'Article',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'VALENCE-BOND STATE; KAGOME-LATTICE; GROUND-STATE; SUPERCONDUCTIVITY; ANTIFERROMAGNET; EXCITATIONS; TOPOLOGY; PHYSICS',
# ...

# %%
b[2][3]
# Out:
# ''

# %%
b[2][3]==True
# Out:
# False

# %%
len(b[2][3])
# Out:
# 0

# %%
'''C1列是作者地址'''
b[0][23]
# Out:
# 'C1'

# %%
b[1][23]
# Out:
# '[Jia, Wei] Shanghai Jiao Tong Univ, Affiliated Peoples Hosp 6, Dept Endocrinol & Metab, Shanghai Key Lab Diabet Mellitus, Shanghai 200030, Peoples R China; [Jia, Wei] Shanghai Jiao Tong Univ, Affiliated Peoples Hosp 6, Dept Endocrinol & Metab, Ctr Translat Med, Shanghai 200030, Peoples R China; [Jia, Wei; Xie, Guoxiang] Univ Hawaii, Ctr Canc, Honolulu, HI 96822 USA; [Jia, Wei; Wang, Xiaoning] Shanghai Univ Tradit Chinese Med, E Inst, Shanghai Municipal Educ Comm, Shanghai, Peoples R China; [Fan, Tai-ping] Univ Cambridge, Dept Pharmacol, Angiogenesis & Tradit Chinese Med Lab, Cambridge CB2 1QJ, England'

# %%
'''DT是文献类型'''
b[0][14]
# Out:
# 'DT'

# %%
b[1][14]
# Out:
# 'Editorial Material'

# %%
'''RP是通讯作者地址'''
b[0][24]
# Out:
# 'RP'

# %%
b[1][24]
# Out:
# 'Jia, W (reprint author), Shanghai Jiao Tong Univ, Affiliated Peoples Hosp 6, Dept Endocrinol & Metab, Shanghai Key Lab Diabet Mellitus, Shanghai 200030, Peoples R China.'

# %%
"Article" in b[2]
# Out:
# True

# %%
g=['Article; Retracted Publication','ni']

# %%
'Article' in g
# Out:
# False

# %%
b[0]
# Out:
# ['上海中医药大学',
#  '\ufeffPT',
#  'AU',
#  'BA',
#  'BE',
#  'GP',
#  'AF',
#  'BF',
#  'CA',
#  'TI',
#  'SO',
#  'SE',
#  'BS',
#  'LA',
#  'DT',
#  'CT',
#  'CY',
#  'CL',
#  'SP',
#  'HO',
#  'DE',
#  'ID',
#  'AB',
#  'C1',
#  'RP',
#  'EM',
#  'RI',
#  'OI',
#  'FU',
#  'FX',
#  'CR',
#  'NR',
#  'TC',
#  'Z9',
#  'U1',
#  'U2',
#  'PU',
#  'PI',
#  'PA',
#  'SN',
#  'EI',
#  'BN',
#  'J9',
#  'JI',
#  'PD',
#  'PY',
#  'VL',
#  'IS',
#  'PN',
#  'SU',
#  'SI',
#  'MA',
#  'BP',
#  'EP',
#  'AR',
#  'DI',
#  'D2',
#  'EA',
#  'EY',
#  'PG',
#  'WC',
#  'SC',
#  'GA',
#  'UT',
#  'PM',
#  'OA',
#  'HC',
#  'HP',
#  'DA',
#  '\n']

# %%
len(b)#与N&S发文记录信息整合中count-81数目相等，检索记录没有减少
# Out:
# 885

# %%
d=[]
for item in b[1:]:
    c=[]
    if "Article" in item:
        c.append(item[0])#校名
        c.append(item[9])#论文题目
        c.append(item[14])#文献类型
        c.append(item[23])#作者地址
        c.append(item[24])#通讯作者地址
        print(c)
        d.append(c)
# Out:
# ['上海交通大学', 'Evidence for a spinon Fermi surface in a triangular-lattice quantum-spin-liquid candidate', 'Article', '[Shen, Yao; Wo, Hongliang; Shen, Shoudong; Pan, Bingying; Wang, Qisi; Hao, Yiqing; Chen, Gang; Zhao, Jun] Fudan Univ, State Key Lab Surface Phys, Shanghai 200433, Peoples R China; [Shen, Yao; Wo, Hongliang; Shen, Shoudong; Pan, Bingying; Wang, Qisi; Hao, Yiqing; Chen, Gang; Zhao, Jun] Fudan Univ, Dept Phys, Shanghai 200433, Peoples R China; [Li, Yao-Dong] Fudan Univ, Sch Comp Sci, Shanghai 200433, Peoples R China; [Li, Yuesheng; Zhang, Qingming] Renmin Univ China, Beijing Key Lab Optoelect Funct Mat & Micronano D, Dept Phys, Beijing 100872, Peoples R China; [Walker, H. C.] STFC, Rutherford Appleton Lab, ISIS Facil, Didcot OX11 0QX, Oxon, England; [Steffens, P.; Boehm, M.] Inst Laue Langevin, 71 Ave Martyrs, F-38042 Grenoble 9, France; [Quintero-Castro, D. L.] Helmholtz Zentrum Berlin Mat & Energie, D-14109 Berlin, Germany; [Harriger, L. W.] NIST, Ctr Neutron Res, Gaithe
# ...

# %%
len(d)
# Out:
# 643

# %%
d[3]
# Out:
# ['上海交通大学',
#  'Article',
# ...

# %%
len(d[3])
# Out:
# 5

# %%
count=0
for i in d:
    if len(i)!=5:
        count+=1
        print(i)

# %%
count
# Out:
# 0

# %%
h=['上海交通大学','中国科学技术大学','中央大学','中山大学（广州）','北京大学','南京大学','台湾大学','大连海事大学','清华大学（北京）']

# %%
e=[]
for i in d:
    e.append(i[4])

# %%
len(e)
# Out:
# 643

# %%
p=[]
for i in d:
    if i[1]=='Genetic studies of body mass index yield new insights for obesity biology':
        print(i[4])
# Out:
# Speliotes, EK (reprint author), Univ Michigan, Dept Internal Med, Div Gastroenterol, Ann Arbor, MI 48109 USA.
# Speliotes, EK (reprint author), Univ Michigan, Dept Internal Med, Div Gastroenterol, Ann Arbor, MI 48109 USA.

# %%
'''
Speliotes, EK (reprint author), Univ Michigan, Dept Internal Med, Div Gastroenterol, Ann Arbor, MI 48109 USA.
可以先找Univ索引，再找逗号索引，删除前半部分或后半部分，然后再找逗号索引，删除另一部分，进而分列出大学

分列出大学后，列表元素相加，将通讯作者添加到首位，然后利用index查找大学索引，最后利用numy.unique()使查找大学的前面唯一，求出集合的长度，
进而推断，大学的权重得分
'''

# %%
len(p)
# Out:
# 2

# %%
q=[]
for i in d:
    q.append(i[4])

# %%
len(q)
# Out:
# 643

# %%
df=pd.DataFrame(np.array(d))

# %%
df.to_csv("C:/Users/rk/Desktop/ns.csv",index=False,encoding='ANSI')
df
# Out:
#             0                                                  1        2  \
# 0      上海交通大学  Evidence for a spinon Fermi surface in a trian...  Article
# 1      上海交通大学  Single-cell RNA-seq identifies a PD-1(hi) ILC ...  Article
# 2      上海交通大学  Pathological alpha-synuclein transmission init...  Article
# 3      上海交通大学  A Pleistocene ice core record of atmospheric O...  Article
# 4      上海交通大学        The genetic architecture of type 2 diabetes  Article
# 5      上海交通大学  Structural basis for activity regulation of ML...  Article
# 6      上海交通大学  Emergence of superconductivity in the canonica...  Article
# 7      上海交通大学  Efficient and stable large-area perovskite sol...  Article
# 8      上海交通大学  Exclusion of leptophilic dark matter models us...  Article
# 9      上海交通大学  Sparse whole-genome sequencing identifies two ...  Article
# 10     上海交通大学  Lanosterol reverses protein aggregation in cat...  Article
# 11     上海交通大学  Directional dominance on stature and cognition...  Article
# ...

# %%
885-634
# Out:
# 251

# %%
result=pd.DataFrame(np.array(b))#将pd.DataFrame(np.array(myarray))写入list
result.to_csv("C:/Users/rk/Desktop/ns.csv",index=False,encoding='ANSI')
result
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-67-63b79061569b> in <module>()
# ----> 1 result=pd.DataFrame(np.array(b))#将pd.DataFrame(np.array(myarray))写入list
#       2 result.to_csv("C:/Users/rk/Desktop/ns.csv",index=False,encoding='ANSI')
#       3 result
#
# MemoryError:

# %%
df

# %%
a=[]
with (open(Folder_Path +'\\'+ file_list[0],encoding='utf-8')) as f:
    z=re.sub(r'.txt','',re.sub(r"[0-9][0-9]*","",file_list[0]))#sub 应该是替换函数，用空替换掉所选择的字符
    for li in f:
        a.append(z+'\t')
        a.append(li)
for fi in file_list[1:]:
    b=[]
    c=[]#新增加个列表是因为文件只能写入字符串，列表不可以
    with (open(Folder_Path +'\\'+ fi,encoding='utf-8')) as f:
        z=re.sub(r'.txt','',re.sub(r"[0-9][0-9]*","",fi))#sub 应该是替换函数，用空替换掉所选择的字符
        print(z)
        for lin in f:
            b.append(z+'\t')#增加了学校名称
            b.append(lin)
        for lins in b[1:]:#过滤掉之前增加的学校名称
            c.append(lins)
    print(len(b))
    print('before del:',c[0])
    del c[0]#之前只过滤掉学校名称，第一行还存在
    print(len(c))
    print('after del:',c[0])
    a.extend(c)

# %%
#第一种方法
np.savetxt("data.txt",data)     #将数组中数据写入到data.txt文件
#第二种方法
np.save("data.txt",data)        #将数组中数据写入到data.txt文件
