# %%
#encoding=utf-8
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r'C:/Users/rk/Desktop/评论.csv',engine='python')

# %%
pd.read_csv?

# %%
len(data)
# Out:
# 1261

# %%
string=""
for i in range(len(data)):
    string+=data.iloc[i,0]

# %%
string
# Out:
# '在我看来，从认可度来说，清北第一梯队；复交第二梯队，部分工科如船舶、机械、cs等方面交大占优，但由于复旦的综合性与均衡性，文理科吊打交大，经管类也领先半个身位，新工科蒸蒸日上，所以我愿意把它排在交大前（去年高考占大头的提前批，分数线上复旦领先交大不少，侧面反映了人民的认可度）；浙大、人大、科大、南大第三梯队，其中浙大靠着雄厚资金和庞大规模可能略胜半筹，有时会靠规模胜过第二梯队。而人大的财经政法方面十分突出，在某些省市受欢迎程度快赶得上复交。科大的科研绝对是没得说，只看科研可排top4，但这也局限了他的受众面，收分可能还是逊于第二梯队。南大感觉近年有些力不从心，天地物化的优势虽说还在，但医工等发展势头没赶上，有吊车尾的危险。注：一二梯队间的差距远大于二三间的差距川大能排16，这就贼离谱不懂就问，为什么人大排名这么靠后丫的我人大排名还不如武大川大?有啥想不到的，软科一直把山大排在这个位置，而且知名度比较高的几个排名中，软科已经算把山大排得低的了。川山吉差不多就是二十名左右的层次。天津大学真就末流985了呗我不管，华科排过武大了就不是野鸡榜北航和北师大差不多水平……当然计算机热，可能略好一点……山师：我一双非师范大学比211工科大学排名还高那是为什么呢？只看软科这几年的榜的话，武大和中大应该反过来说吧本来看到我开已经第19了，痛心疾首，哀其不幸，怒其不争，我是爱南开的呀，但当今之南开非要自绝于......诶，原来就比人大低一名啊，还可以吧，挺好的。一般公认的第三是三所复交浙，最多再加个人大，当然偶尔湖北广东人会跳出来吹武中华撕撕华五…录取分数线是非常非常非常片面的1.受地域影响兰州大学录取分数线在大多数省份不如苏州大学，然而兰大实力强于苏大哈尔滨工业大学（深圳）实力远远不如本部，然而分数线在某些省份比本部高四五十分2.受专业设置影响哈尔滨工业大学（深圳）招生专业几乎全为信息类，而同城的中大（部分学院在深圳）有生化环材类的专业必然会拖后腿，使得部分考生求稳放弃中大类似的还有北京理工大学，近年将一些天冷专业和热门专业打包在一起大类招生，使得账面上的专业很漂亮从而分数线大幅提高在这里再举一个例子——上海财经大学在我们省，本科一批次上财的分数线并肩华五，有时比北大医学部还高，一般可以甩开央财二三十分，而在国家专项批次，如果央财分数线是600分的话，上财轮落到了566，最低时
# ...

# %%
wordcloud = WordCloud().generate(string)

# %%
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
#encoding=gbk
import jieba.analyse
from PIL import Image,ImageSequence
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud,ImageColorGenerator
lyric= ''
f=open(r'C:\Users\rk\Desktop\日志.txt','r',encoding='utf-8')
for i in f:
  lyric+=f.read()

result=jieba.analyse.textrank(lyric,topK=50,withWeight=True)
keywords = dict()
for i in result:
  keywords[i[0]]=i[1]
print(keywords)


image= Image.open(r'C:\Users\rk\Desktop\201706130803413.jpg')
graph = np.array(image)
wc = WordCloud(font_path='./fonts/simhei.ttf',background_color='White',max_words=50,mask=graph)
wc.generate_from_frequencies(keywords)
image_color = ImageColorGenerator(graph)
plt.imshow(wc)
plt.imshow(wc.recolor(color_func=image_color))
plt.axis("off")
plt.show()
wc.to_file('dream.png')
# Out:
# {'天神': 1.0, '盘古': 0.930553263388125, '生命': 0.8838678098094098, '天道': 0.7877971729509828, '世界': 0.7767284849950792, '领悟': 0.7354784414763682, '祖神': 0.7250706291317383, '真神': 0.6764155102446792, '佛祖': 0.6727160454063568, '孕育出': 0.6616357185632656, '诞生': 0.6323164490126616, '上古': 0.6323160319969776, '天地': 0.6128498994996175, '首领': 0.5741612350573573, '指数': 0.553993387251729, '地盘': 0.47756034967199995, '大道': 0.47456915371316966, '不惜': 0.4165871036726404, '掌握': 0.4165147037952144, '调查': 0.40720246047657205, '程序验证': 0.40586016832208077, '收集': 0.40440556280482365, '精彩': 0.3996423968610179, '火神': 0.39544136565875687, '强者': 0.38786806594559076, '组织': 0.38268844834363386, '道人': 0.34776864016650555, '命运': 0.346265988380234, '生来': 0.3446303431715724, '无比': 0.3336651303368175, '实体书': 0.32432012280297556, '存在': 0.3239785224815652, '境界': 0.32000123832208593, '开始': 0.3160048701696862, '出身': 0.3050144850127294, '燃烧': 0.30189769275902567, '最强者': 0.3017811403106718, '占地': 0.295558901634775, '隐居': 0.295
# ...

# %%
#encoding=gbk
import jieba.analyse
from PIL import Image,ImageSequence
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud,ImageColorGenerator
# lyric= ''
# f=open(r'C:\Users\rk\Desktop\日志.txt','r',encoding='utf-8')
# for i in f:
#   lyric+=f.read()

result=jieba.analyse.textrank(string,topK=50,withWeight=True)
keywords = dict()
for i in result:
  keywords[i[0]]=i[1]
print(keywords)


image= Image.open(r'C:\Users\rk\Desktop\20.png')
graph = np.array(image)
wc = WordCloud(font_path='./fonts/simhei.ttf',background_color='White',max_words=50,mask=graph)
wc.generate_from_frequencies(keywords)
image_color = ImageColorGenerator(graph)
plt.imshow(wc)
plt.imshow(wc.recolor(color_func=image_color))
plt.axis("off")
plt.show()
wc.to_file(r'C:\Users\rk\Desktop\dream.png')
# Out:
# {'排名': 1.0, '大学': 0.658734631274203, '学校': 0.4862577574651557, '没有': 0.2975285490935472, '高校': 0.24178595660802535, '专业': 0.19390933705670763, '学科': 0.1666458189539156, '学生': 0.16565427723913292, '榜单': 0.16040658926613238, '指标': 0.1561763531073365, '中国': 0.13813139208033942, '高考': 0.13582246821124344, '院校': 0.11892791902828082, '评价': 0.1153115152493466, '一流': 0.11418588553994685, '社会': 0.10456000395315052, '觉得': 0.10372672163030776, '实力': 0.1005284080344377, '排行榜': 0.09925276690883837, '分数线': 0.0978084428910638, '学院': 0.09273218931224338, '应该': 0.09030738543143782, '大家': 0.08938325346427604, '上海': 0.08931795230226273, '时候': 0.08811738627267789, '看到': 0.08698914619970766, '软科': 0.0850265087081005, '服务': 0.08453383008776641, '全国': 0.08142097849450758, '参考': 0.08140918053960458, '世界': 0.08045779268896591, '加油': 0.07718861668611923, '分数': 0.07716200310996431, '可能': 0.0765072095905241, '知道': 0.07312589322395704, '母校': 0.07024032843864925, '数据': 0.06806873842421743, '生源': 0.067538702684559
# ...
