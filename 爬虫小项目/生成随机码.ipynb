# %%
import random

# %%
al='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789'

# %%
li_al=list(al)

# %%
random.choice(li_al)
# Out:
# 'R'

# %%
import csv

# %%
############首先对Mapp.csv原文件数据去重，删除数据重复的项目######################
lis_a = []#创建空白列表，存储文件内容
csv_reader=csv.reader(open(r'C:\Users\rk\Desktop\rando.csv'))

# %%
for element in csv_reader:
    lis_a.append(element)#逐行读入数据，写入列表

# %%
lis_a[:9]
# Out:
# [['personCode', 'accessCode'],
#  ['pid201900001', 'Tvh1x'],
#  ['pid201900002', 'WIWmf'],
#  ['pid201900003', 'ku6a5'],
#  ['pid201900004', 'iiu0W'],
#  ['pid201900005', 'rGAOp'],
#  ['pid201900006', 'C3e8b'],
#  ['pid201900007', 'saLiK'],
#  ['pid201900008', 'iwz9h']]

# %%
2680

# %%
del lis_a[0]

# %%
b=[]
for item in lis_a:
    b.append(item[1])

# %%
count=0
accesscode=[]

# %%
while True:
    a=random.choice(li_al)
    b=random.choice(li_al)
    c=random.choice(li_al)
    d=random.choice(li_al)
    e=random.choice(li_al)
    code=a+b+c+d+e
    print(code)
    if code not in b:
        accesscode.append(code)
        count+=1
    if count==2680:
        break
# Out:
# 02zZj
# PgsNw
# R3V5Z
# 2VuH0
# uBuBJ
# 82ayO
# I4wtO
# E1xVa
# ICWe3
# mVZIW
# MltCO
# yhmcV
# rDnOj
# AiLTS
# D4tE9
# n7PBZ
# RMeZv
# q3VSY
# XMOTH
# rXTRG
# vPjzO
# RCFO0
# qtRDe
# FfyDK
# 8zxOd
# P0EHU
# KBQ2h
# sQdrh
# khzQp
# S2lqA
# 3SdrM
# Xc8Hc
# zdljq
# ueFtE
# 7YwU5
# PGIcJ
# JKp0O
# wxuDO
# 1olBA
# qThVM
# MqtLr
# yfHF4
# N8nlx
# L7evK
# HOK87
# DjLT3
# ikXwi
# JvtYY
# ba74h
# kUapG
# 2V8Jt
# wSZbx
# V4If8
# TiirK
# yFSfL
# 5lnVl
# MxRGe
# mvjUB
# u07Qp
# 5sOnh
# HMamD
# VjzrH
# 5yogW
# NMYFW
# AOjj5
# JLvVO
# MHdCm
# HUBe7
# ISfdY
# FQLZb
# ekPH8
# ajixe
# Wxj43
# QzEju
# jLVR4
# JB97q
# a8Iow
# lbCbR
# vr4M1
# r0Zt2
# 58tSK
# 1081R
# tgffK
# nQRdw
# PCpL6
# EQpyU
# vQf5X
# H3jIg
# Ei8FT
# oicPp
# d4WMK
# Lk84B
# JDoUB
# 4CG0y
# lPCgG
# KxlPu
# x2H3R
# BXiv5
# yD7BX
# VBU8A
# iS0Xs
# IX1QO
# ASGOQ
# MLfV7
# PlO3u
# XeiJX
# iYSM4
# RBhER
# APb2b
# hlruw
# ks995
# W040W
# 0862F
# gBRaE
# lUU0N
# vwchA
# BS2YG
# WH4ez
# y6kZJ
# 7uYig
# VNkmg
# FDpde
# lN8Ll
# qZFrW
# PfBuB
# ...

# %%
accesscode
# Out:
# ['02zZj',
#  'PgsNw',
#  'R3V5Z',
#  '2VuH0',
#  'uBuBJ',
#  '82ayO',
#  'I4wtO',
#  'E1xVa',
#  'ICWe3',
#  'mVZIW',
#  'MltCO',
#  'yhmcV',
#  'rDnOj',
#  'AiLTS',
#  'D4tE9',
#  'n7PBZ',
#  'RMeZv',
#  'q3VSY',
#  'XMOTH',
#  'rXTRG',
#  'vPjzO',
#  'RCFO0',
#  'qtRDe',
#  'FfyDK',
#  '8zxOd',
#  'P0EHU',
#  'KBQ2h',
#  'sQdrh',
#  'khzQp',
#  'S2lqA',
#  '3SdrM',
#  'Xc8Hc',
#  'zdljq',
#  'ueFtE',
#  '7YwU5',
#  'PGIcJ',
#  'JKp0O',
#  'wxuDO',
#  '1olBA',
#  'qThVM',
#  'MqtLr',
#  'yfHF4',
#  'N8nlx',
#  'L7evK',
#  'HOK87',
#  'DjLT3',
#  'ikXwi',
#  'JvtYY',
#  'ba74h',
#  'kUapG',
#  '2V8Jt',
#  'wSZbx',
#  'V4If8',
#  'TiirK',
#  'yFSfL',
#  '5lnVl',
#  'MxRGe',
#  'mvjUB',
#  'u07Qp',
#  '5sOnh',
#  'HMamD',
#  'VjzrH',
#  '5yogW',
#  'NMYFW',
#  'AOjj5',
#  'JLvVO',
#  'MHdCm',
#  'HUBe7',
#  'ISfdY',
#  'FQLZb',
#  'ekPH8',
#  'ajixe',
#  'Wxj43',
#  'QzEju',
#  'jLVR4',
#  'JB97q',
#  'a8Iow',
#  'lbCbR',
#  'vr4M1',
#  'r0Zt2',
#  '58tSK',
#  '1081R',
#  'tgffK',
# ...

# %%
import pandas as pd
import numpy as py

# %%
outdata=pd.DataFrame(py.array(accesscode))

# %%
outdata.to_csv(r'C:\Users\rk\Desktop\randooo.csv')

# %%
outdata
# Out:
#           0
# 0     02zZj
# 1     PgsNw
# 2     R3V5Z
# 3     2VuH0
# 4     uBuBJ
# 5     82ayO
# 6     I4wtO
# 7     E1xVa
# 8     ICWe3
# 9     mVZIW
# 10    MltCO
# 11    yhmcV
# 12    rDnOj
# 13    AiLTS
# 14    D4tE9
# 15    n7PBZ
# 16    RMeZv
# 17    q3VSY
# 18    XMOTH
# 19    rXTRG
# 20    vPjzO
# 21    RCFO0
# 22    qtRDe
# 23    FfyDK
# 24    8zxOd
# 25    P0EHU
# 26    KBQ2h
# 27    sQdrh
# 28    khzQp
# 29    S2lqA
# ...     ...
# 2650  5CxNt
# 2651  iHRHB
# 2652  fNbpe
# 2653  YntlQ
# 2654  rt1uT
# 2655  SggLR
# 2656  3BzxB
# 2657  S130h
# 2658  zReo5
# 2659  UFa8i
# 2660  W3aM3
# 2661  xmwCH
# 2662  JNyZU
# 2663  YWWCW
# 2664  by9Kr
# 2665  9hCWR
# 2666  wyYFE
# 2667  woxSW
# 2668  B4lJ0
# 2669  7UbO7
# 2670  EVMKA
# 2671  1iBl9
# 2672  IHKxj
# 2673  xfEfg
# 2674  g052T
# 2675  shJK7
# 2676  1xW4k
# 2677  cQPsm
# 2678  M50lW
# 2679  4TFP1
#
# [2680 rows x 1 columns]
