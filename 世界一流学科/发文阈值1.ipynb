# %%
import csv,os
import pandas as pd
import numpy as np
import re

# %%
#读入csv中的数据，（导入检索式）
a = []
csv_reader=csv.reader(open(r'C:\Users\rk\Desktop\yuzhi.csv',encoding='GB18030'))#打开文件
for row in csv_reader:
    a.append(row)#将读入的数据赋值给列表a

# %%
a[0]
# Out:
# ['Subject', 'Institution', 'Pub', 'CNCI', '%IC']

# %%
a[1]
# Out:
# ['Aerospace Engineering', 'Aalborg University', '3', '0.7127', '33.33333333']

# %%
del a[0]

# %%
a[0]
# Out:
# ['Aerospace Engineering', 'Aalborg University', '3', '0.7127', '33.33333333']

# %%
b=[]
b.append(a[0][0])
b.append(a[0][1:])

# %%
b
# Out:
# ['Aerospace Engineering', ['Aalborg University', '3', '0.7127', '33.33333333']]

# %%
c=[]
for item in a:
    b=[]
    b.append(item[0])
    b.append(item[1:])
    c.append(b)

# %%
c[0]
# Out:
# ['Aerospace Engineering', ['Aalborg University', '3', '0.7127', '33.33333333']]

# %%
c[1:5]
# Out:
# [['Aerospace Engineering',
#   ['Aalto University', '13', '0.779823077', '46.15384615']],
#  ['Aerospace Engineering', ['Aarhus University', '6', '8.66775', '100']],
#  ['Aerospace Engineering', ['Abu Dhabi University', '1', '0.5561', '100']],
#  ['Aerospace Engineering',
#   ['Academic Center for Dentistry Amsterdam', '3', '1.935033333', '100']]]

# %%
####################运用此程序的前提是：先在原文件里做好分类汇总####################################
final_lis=[]
counter=0
while True:#为了是for循环中的起始值counter的改变，for进入循环后，起始值不再改变，
    for item_1 in c[counter:]:
        diction=[]
        lis_c=[]
        initial_s=0
        lis_c.append(item_1[1])#将第一个期刊加入列表，在此处加入是防止仅出现一次而忽略
        for item_2 in c[counter+1:]:
            if item_1[0]==item_2[0]:
                lis_c.append(item_2[1])#将相同的期刊加入列表
                initial_s+=1 #每找到一个相同的就把initial_s加一，     
        diction.append(item_1[0])
        diction.append(lis_c)
        final_lis.append(diction)
        break#为了使for循环中的起始值改变，循环一次后利用break强制退出for循环，利用while进入下一次循环
    counter=counter+initial_s+1
    if counter>=len(c):#为了使while循环跳出,当大于列表长度的时候跳出循环
        break

# %%
final_lis[0]
# Out:
# ['Aerospace Engineering',
#  [['Aalborg University', '3', '0.7127', '33.33333333'],
#   ['Aalto University', '13', '0.779823077', '46.15384615'],
#   ['Aarhus University', '6', '8.66775', '100'],
#   ['Abu Dhabi University', '1', '0.5561', '100'],
#   ['Academic Center for Dentistry Amsterdam', '3', '1.935033333', '100'],
#   ['Academy of Athens', '1', '0.1775', '100'],
#   ['Academy of Mathematics & System Sciences, CAS', '1', '1.2115', '100'],
#   ['Adam Mickiewicz University', '5', '0.41408', '20'],
#   ['Adi Shankara Institute of Engineering & Technology', '1', '0.5048', '0'],
#   ['AGH University of Science & Technology', '1', '1.1122', '100'],
#   ['Aichi University Education', '1', '0.1533', '100'],
#   ['Ain Shams University', '1', '0.2524', '100'],
#   ['Air Force Engineering University', '56', '1.193607143', '8.928571429'],
#   ['Aix-Marseille Universite', '20', '1.55219', '60'],
#   ['Ajou University', '2', '0.44225', '0'],
#   ['Akdeniz University', '1', '15.2995', '0'],
# ...

# %%
final_lis[0][1]
# Out:
# [['Aalborg University', '3', '0.7127', '33.33333333'],
#  ['Aalto University', '13', '0.779823077', '46.15384615'],
#  ['Aarhus University', '6', '8.66775', '100'],
#  ['Abu Dhabi University', '1', '0.5561', '100'],
#  ['Academic Center for Dentistry Amsterdam', '3', '1.935033333', '100'],
#  ['Academy of Athens', '1', '0.1775', '100'],
#  ['Academy of Mathematics & System Sciences, CAS', '1', '1.2115', '100'],
#  ['Adam Mickiewicz University', '5', '0.41408', '20'],
#  ['Adi Shankara Institute of Engineering & Technology', '1', '0.5048', '0'],
#  ['AGH University of Science & Technology', '1', '1.1122', '100'],
#  ['Aichi University Education', '1', '0.1533', '100'],
#  ['Ain Shams University', '1', '0.2524', '100'],
#  ['Air Force Engineering University', '56', '1.193607143', '8.928571429'],
#  ['Aix-Marseille Universite', '20', '1.55219', '60'],
#  ['Ajou University', '2', '0.44225', '0'],
#  ['Akdeniz University', '1', '15.2995', '0'],
# ...

# %%
final_lis[0][1][0]
# Out:
# ['Aalborg University', '3', '0.7127', '33.33333333']

# %%
final_lis[0][1][0][1]
# Out:
# '3'

# %%
len(final_lis[0][1])
# Out:
# 1532

# %%
for it in final_lis:
    print(it[0])
# Out:
# Aerospace Engineering
# Agricultural Economics
# Agricultural Engineering
# Agricultural Sciences
# Atmospheric Science
# Automation & Control
# Biological Sciences
# Biomedical Engineering
# Biotechnology
# Business Administration
# Chemical Engineering
# Chemistry
# Civil Engineering
# Clinical Medicine
# Communication
# Computer Science & Engineering
# Dentistry & Oral Sciences
# Earth Sciences
# Ecology
# Economics
# Education
# Electrical & Electronic Engineering
# Energy Science & Engineering
# Environmental Science & Engineering
# Finance
# Food Science & Technology
# Geography
# Geological Engineering
# Hospitality & Tourism Management
# Human Biological Sciences
# Instruments Science & Technology
# Law
# Library & Information Science
# Management
# Marine/Ocean Engineering
# Materials Science & Engineering
# Mathematics
# Mechanical Engineering
# Medical Technology
# Metallurgical Engineering
# Mining & Mineral Engineering
# Nanoscience & Nanotechnology
# Nursing
# ...

# %%
final_lis[13][0]
# Out:
# 'Clinical Medicine'

# %%
result=[]
result.append(['Subject','counter','counter_25','cnci_25_max','Institute_max','counter_50','cnci_50_max','Institute_max',\
              'counter_100','cnci_100_max','Institute_max','counter_125','cnci_125_max','Institute_max','counter_150','cnci_150_max','Institute_max',\
              'counter_200','cnci_200_max','Institute_max','counter_250','cnci_250_max','Institute_max','counter_300','cnci_300_max','Institute_max',\
              'counter_400','cnci_400_max','Institute_max','counter_500','cnci_500_max','Institute_max','counter_750','cnci_750_max','Institute_max',\
              'counter_1000','cnci_1000_max','Institute_max',])
for item_3 in final_lis[13:14]:
    subject=[]
    counter_25=0
    counter_50=0
    counter_100=0
    counter_125=0
    counter_150=0
    counter_200=0
    counter_250=0
    counter_300=0
    counter_400=0
    counter_500=0
    counter_750=0
    counter_1000=0
    cnci_25=['0']
    cnci_50=['0']
    cnci_100=['0']
    cnci_125=['0']
    cnci_150=['0']
    cnci_200=['0']
    cnci_250=['0']
    cnci_300=['0']
    cnci_400=['0']
    cnci_500=['0']
    cnci_750=['0']
    cnci_1000=['0']
    subject.append(item_3[0])
    subject.append(len(item_3[1]))
    for item_4 in item_3[1]:
        if int(item_4[1])>=25:
            counter_25+=1
            cnci_25.append(item_4[2])
        if int(item_4[1])>=50:
            counter_50+=1
            cnci_50.append(item_4[2])
        if int(item_4[1])>=100:
            counter_100+=1
            cnci_100.append(item_4[2])
        if int(item_4[1])>=125:
            counter_125+=1
            cnci_125.append(item_4[2])
        if int(item_4[1])>=150:
            counter_150+=1
            cnci_150.append(item_4[2])
        if int(item_4[1])>=200:
            counter_200+=1
            cnci_200.append(item_4[2])
        if int(item_4[1])>=250:
            counter_250+=1
            cnci_250.append(item_4[2])
        if int(item_4[1])>=300:
            counter_300+=1
            cnci_300.append(item_4[2])
        if int(item_4[1])>=400:
            counter_400+=1
            cnci_400.append(item_4[2])
        if int(item_4[1])>=500:
            counter_500+=1
            cnci_500.append(item_4[2])
        if int(item_4[1])>=750:
            counter_750+=1
            cnci_750.append(item_4[2])
        if int(item_4[1])>=1000:
            counter_1000+=1
            cnci_1000.append(item_4[2])
            
    subject.append(counter_25)
    subject.append(max(cnci_25))
    flag1=0
    for item_4 in item_3[1]:
        if max(cnci_25)!='0' and (max(cnci_25) in item_4):
            subject.append(item_4[0])
            flag1=1
            break
    if flag1== 0:
        subject.append('0')
        
    subject.append(counter_50)
    subject.append(max(cnci_50))
    flag2=0
    for item_4 in item_3[1]:
        if max(cnci_50)!='0' and (max(cnci_50) in item_4):
            subject.append(item_4[0])
            flag2=1
            break
    if flag2==0:
        subject.append('0')
        
    subject.append(counter_100)
    subject.append(max(cnci_100))
    flag3=0
    for item_4 in item_3[1]:
        if max(cnci_100)!='0' and (max(cnci_100) in item_4):
            subject.append(item_4[0])
            flag3=1
            break
    if flag3==0:
        subject.append('0')
        
    subject.append(counter_125)
    subject.append(max(cnci_125))
    flag9=0
    for item_4 in item_3[1]:
        if max(cnci_125)!='0' and (max(cnci_125) in item_4):
            subject.append(item_4[0])
            flag9=1
            break
    if flag9==0:
        subject.append('0')
        
    subject.append(counter_150)
    subject.append(max(cnci_150))
    flag4=0
    for item_4 in item_3[1]:
        if max(cnci_150)!='0' and (max(cnci_150) in item_4):
            subject.append(item_4[0])
            flag4=1
            break
    if flag4==0:
        subject.append('0')
        
    subject.append(counter_200)
    subject.append(max(cnci_200))
    flag5=0
    for item_4 in item_3[1]:
        if max(cnci_200)!='0' and (max(cnci_200) in item_4):
            subject.append(item_4[0])
            flag5=1
            break
    if flag5==0:
        subject.append('0')
    
    subject.append(counter_250)
    subject.append(max(cnci_250))
    flag10=0
    for item_4 in item_3[1]:
        if max(cnci_250)!='0' and (max(cnci_250) in item_4):
            subject.append(item_4[0])
            flag10=1
            break
    if flag10==0:
        subject.append('0')
        
    subject.append(counter_300)
    subject.append(max(cnci_300))
    flag6=0
    for item_4 in item_3[1]:
        if max(cnci_300)!='0' and (max(cnci_300) in item_4):
            subject.append(item_4[0])
            flag6=1
            break
    if flag6==0:
        subject.append('0')
        
    subject.append(counter_400)
    subject.append(max(cnci_400))
    flag7=0
    for item_4 in item_3[1]:
        if max(cnci_400)!='0' and (max(cnci_400) in item_4):
            subject.append(item_4[0])
            flag7=1
            break
    if flag7==0:
        subject.append('0')
        
    subject.append(counter_500)
    subject.append(max(cnci_500))
    flag8=0
    for item_4 in item_3[1]:
        if max(cnci_500)!='0' and (max(cnci_500) in item_4):
            subject.append(item_4[0])
            flag8=1
            break
    if flag8==0:
        subject.append('0')

    subject.append(counter_750)
    subject.append(max(cnci_750))
    flag11=0
    for item_4 in item_3[1]:
        if max(cnci_750)!='0' and (max(cnci_750) in item_4):
            subject.append(item_4[0])
            flag11=1
            break
    if flag11==0:
        subject.append('0')

    subject.append(counter_1000)
    subject.append(max(cnci_1000))
    flag12=0
    for item_4 in item_3[1]:
        if max(cnci_1000)!='0' and (max(cnci_1000) in item_4):
            subject.append(item_4[0])
            flag12=1
            break
    if flag12==0:
        subject.append('0')

    result.append(subject)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-d3e7a4928090> in <module>()
#     123
#     124     subject.append(counter_200)
# --> 125     subject.append(max(cnci_200))
#     126     flag5=0
#     127     for item_4 in item_3[1]:
#
# TypeError: '>' not supported between instances of 'float' and 'str'

# %%
result
# Out:
# [['Subject',
#   'counter',
#   'counter_25',
#   'cnci_25_max',
#   'Institute_max',
#   'counter_50',
#   'cnci_50_max',
#   'Institute_max',
#   'counter_100',
#   'cnci_100_max',
#   'Institute_max',
#   'counter_125',
#   'cnci_125_max',
#   'Institute_max',
#   'counter_150',
#   'cnci_150_max',
#   'Institute_max',
#   'counter_200',
#   'cnci_200_max',
#   'Institute_max',
#   'counter_250',
#   'cnci_250_max',
#   'Institute_max',
#   'counter_300',
#   'cnci_300_max',
#   'Institute_max',
#   'counter_400',
#   'cnci_400_max',
#   'Institute_max',
#   'counter_500',
#   'cnci_500_max',
#   'Institute_max',
#   'counter_750',
#   'cnci_750_max',
#   'Institute_max',
#   'counter_1000',
#   'cnci_1000_max',
#   'Institute_max'],
#  ['Clinical Medicine',
#   4689,
#   2574,
#   '9.779084694',
#   'Danube University Krems',
#   2061,
#   '9.779084694',
#   'Danube University Krems',
#   1578,
#   '9.779084694',
#   'Danube University Krems',
#   1425,
#   '9.779084694',
# ...

# %%
cnci_200
# Out:
# ['0',
#  '2.263830773',
#  '1.995891677',
#  '0.392326327',
#  '1.10800197',
#  '0.75372381',
#  '1.393966667',
#  '0.505380586',
#  '0.5068125',
#  '5.65805169',
#  '0.388733977',
#  '0.395704578',
#  '0.479870021',
#  '3.89309344',
#  '1.054290617',
#  '0.91397357',
#  '1.413906599',
#  '1.686387018',
#  '0.905604009',
#  '0.523660568',
#  '0.779736634',
#  '0.707983881',
#  '1.57678935',
#  '2.094107021',
#  '0.975665296',
#  '6.465564762',
#  '1.793462172',
#  '2.350971482',
#  '5.076467374',
#  '0.903004411',
#  '0.812295247',
#  '0.75933012',
#  '1.912702805',
#  '1.518080112',
#  '1.041141926',
#  '0.985808364',
#  '0.833377237',
#  '0.817470213',
#  '1.101502489',
#  '0.415573495',
#  '1.377166209',
#  '1.097869054',
#  '6.521826261',
#  '1.404847171',
#  '1.44373406',
#  '2.630329046',
#  '1.632149724',
#  '1.888809914',
#  '0.430240833',
#  '0.517315888',
#  '2.058146731',
#  '1.187759506',
#  '3.118300458',
#  '1.059407028',
#  '0.380194737',
#  '1.877502273',
# ...

# %%
len(cnci_200)
# Out:
# 1179

# %%
'11.00893565' in cnci_200
# Out:
# True

# %%
9.492004695 in cnci_200
# Out:
# False

# %%
max(cnci_200)
# Out:
# '9.492004695'

# %%
#################################### 保存文件 ###############################
result_latest=pd.DataFrame(np.array(result))#将pd.DataFrame(np.array(myarray))写入list
result_latest.to_csv("C:/Users/rk/Desktop/fawenyuzhi67.csv",index=False,encoding='GB18030')
result
# Out:
# [['Subject',
#   'counter',
#   'counter_25',
#   'cnci_25_max',
#   'Institute_max',
#   'counter_50',
#   'cnci_50_max',
#   'Institute_max',
#   'counter_100',
#   'cnci_100_max',
#   'Institute_max',
#   'counter_125',
#   'cnci_125_max',
#   'Institute_max',
#   'counter_150',
#   'cnci_150_max',
#   'Institute_max',
#   'counter_200',
#   'cnci_200_max',
#   'Institute_max',
#   'counter_250',
#   'cnci_250_max',
#   'Institute_max',
#   'counter_300',
#   'cnci_300_max',
#   'Institute_max',
#   'counter_400',
#   'cnci_400_max',
#   'Institute_max',
#   'counter_500',
#   'cnci_500_max',
#   'Institute_max',
#   'counter_750',
#   'cnci_750_max',
#   'Institute_max',
#   'counter_1000',
#   'cnci_1000_max',
#   'Institute_max'],
#  ['Aerospace Engineering',
#   1532,
#   170,
#   '3.130375758',
#   'Princeton University',
#   80,
#   '1.950663462',
#   'York University - Canada',
#   28,
#   '1.939482',
#   'University of Naples Federico II',
#   21,
#   '1.654424466',
# ...

# %%
for item in result:
    print(len(item))
# Out:
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
# 38
