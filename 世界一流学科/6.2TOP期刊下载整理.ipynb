# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import os
import csv
import pandas as pd
import numpy as np

# %%
############################################################################
######################  第一部分  #########################################
####################   下载文件  ######################################

# %%
"""
web of science 下载ISSN账号
Incite:602281532@qq.com
密码：rank2016!

"""
# Out:
# '\nweb of science 下载ISSN账号\nIncite:602281532@qq.com\n密码：rank2016!\n\n'

# %%
browser = webdriver.Chrome('C:/Users/rk/Desktop/chromedriver.exe') #锁定浏览器
browser.get("http://jcr.incites.thomsonreuters.com/JCRJournalHomeAction.action")#打开主页面

# %%
##################################################################################

# %%
#打开页面后，直接手动点击至下面的程序

# %%
#########################################################################

# %%
inputs=browser.find_elements_by_xpath('//*[@id="categorySelectionView"]/div/label/input')#查找所有学科

# %%
inputs2=browser.find_elements_by_xpath('//*[@id="categorySelectionView"]/div/label/span')#查找所有学科

# %%
inputs2[0].text
# Out:
# 'ACOUSTICS'

# %%
counter=0

# %%
for index,la in enumerate(inputs[counter:]):#程序中断后会从中断的地方开始循环，若想每循环一次，counter都改变一次，则需要将counter设置在for循环体外
    la.click()#点击学科分类
    browser.find_element_by_xpath('//*[@id="skip-to-content"]/div/div[2]/div[1]/div[9]/div[3]/a[2]').click()#点击summit
    
    browser.find_element_by_xpath('//*[@id="action_export"]/a').click()#点击下载
    browser.find_element_by_xpath('//*[@id="popup"]/div/ul/li[2]/a').click()#点击csv
    category=inputs2[index].text
    la.click()#再次点击上面的学科分类以取消选择
    fil=r'C:\Users\rk\Downloads'+'\\'+category+'.csv'#文件名及路径
    while True:
        try:
            os.rename(r'C:\Users\rk\Downloads\JournalHomeGrid.csv',fil)#对下载的文件修改文件名
        except:
            time.sleep(1)
        else:
            break
    counter+=1

# %%
#####################################################################################
##############################  第二部分 ##################################
######################   合并文件，添加学科分类   ##################

# %%
Folder_Path =r'C:\Users\rk\Downloads\227期刊'        #要拼接的文件夹及其完整路径
SaveFile_Path =  r'C:\Users\rk\Downloads\allresult'       #拼接后要保存的文件路径
#SaveFile_Name = r'all.csv'              #合并后要保存的文件名    
os.chdir(Folder_Path)#修改当前工作目录
file_list = os.listdir() #将该文件夹下的所有文件名存入一个列表

# %%
file_list
# Out:
# ['ACOUSTICS.csv',
#  'AGRICULTURAL ECONOMICS & POLICY.csv',
#  'AGRICULTURAL ENGINEERING.csv',
#  'AGRICULTURE, DAIRY & ANIMAL SCIENCE.csv',
#  'AGRICULTURE, MULTIDISCIPLINARY.csv',
#  'AGRONOMY.csv',
#  'ALLERGY.csv',
#  'ANATOMY & MORPHOLOGY.csv',
#  'ANDROLOGY.csv',
#  'ANESTHESIOLOGY.csv',
#  'ANTHROPOLOGY.csv',
#  'AREA STUDIES.csv',
#  'ASTRONOMY & ASTROPHYSICS.csv',
#  'AUDIOLOGY & SPEECH-LANGUAGE PATHOLOGY.csv',
#  'AUTOMATION & CONTROL SYSTEMS.csv',
#  'BEHAVIORAL SCIENCES.csv',
#  'BIOCHEMICAL RESEARCH METHODS.csv',
#  'BIOCHEMISTRY & MOLECULAR BIOLOGY.csv',
#  'BIODIVERSITY CONSERVATION.csv',
#  'BIOLOGY.csv',
#  'BIOPHYSICS.csv',
#  'BIOTECHNOLOGY & APPLIED MICROBIOLOGY.csv',
#  'BUSINESS, FINANCE.csv',
#  'BUSINESS.csv',
#  'CARDIAC & CARDIOVASCULAR SYSTEMS.csv',
#  'CELL & TISSUE ENGINEERING.csv',
#  'CELL BIOLOGY.csv',
#  'CHEMISTRY, ANALYTICAL.csv',
#  'CHEMISTRY, APPLIED.csv',
#  'CHEMISTRY, INORGANIC & NUCLEAR.csv',
#  'CHEMISTRY, MEDICINAL.csv',
#  'CHEMISTRY, MULTIDISCIPLINARY.csv',
#  'CHEMISTRY, ORGANIC.csv',
#  'CHEMISTRY, PHYSICAL.csv',
#  'CLINICAL NEUROLOGY.csv',
#  'COMMUNICATION.csv',
#  'COMPUTER SCIENCE, ARTIFICIAL INTELLIGENCE.csv',
#  'COMPUTER SCIENCE, CYBERNETICS.csv',
#  'COMPUTER SCIENCE, HARDWARE & ARCHITECTURE.csv',
#  'COMPUTER SCIENCE, INFORMATION SYSTEMS.csv',
#  'COMPUTER SCIENCE, INTERDISCIPLINARY APPLICATIONS.csv',
#  'COMPUTER SCIENCE, SOFTWARE ENGINEERING.csv',
#  'COMPUTER SCIENCE, THEORY & METHODS.csv',
#  'CONSTRUCTION & BUILDING TECHNOLOGY.csv',
#  'CRIMINOLOGY & PENOLOGY.csv',
#  'CRITICAL CARE MEDICINE.csv',
#  'CRYSTALLOGRAPHY.csv',
#  'CULTURAL STUDIES.csv',
#  'DEMOGRAPHY.csv',
#  'DENTISTRY, ORAL SURGERY & MEDICINE.csv',
#  'DERMATOLOGY.csv',
#  'DEVELOPMENTAL BIOLOGY.csv',
#  'ECOLOGY.csv',
#  'ECONOMICS.csv',
#  'EDUCATION & EDUCATIONAL RESEARCH.csv',
#  'EDUCATION, SCIENTIFIC DISCIPLINES.csv',
#  'EDUCATION, SPECIAL.csv',
#  'ELECTROCHEMISTRY.csv',
#  'EMERGENCY MEDICINE.csv',
#  'ENDOCRINOLOGY & METABOLISM.csv',
#  'ENERGY & FUELS.csv',
#  'ENGINEERING, AEROSPACE.csv',
#  'ENGINEERING, BIOMEDICAL.csv',
#  'ENGINEERING, CHEMICAL.csv',
#  'ENGINEERING, CIVIL.csv',
#  'ENGINEERING, ELECTRICAL & ELECTRONIC.csv',
#  'ENGINEERING, ENVIRONMENTAL.csv',
#  'ENGINEERING, GEOLOGICAL.csv',
#  'ENGINEERING, INDUSTRIAL.csv',
#  'ENGINEERING, MANUFACTURING.csv',
#  'ENGINEERING, MARINE.csv',
#  'ENGINEERING, MECHANICAL.csv',
#  'ENGINEERING, MULTIDISCIPLINARY.csv',
#  'ENGINEERING, OCEAN.csv',
#  'ENGINEERING, PETROLEUM.csv',
#  'ENTOMOLOGY.csv',
#  'ENVIRONMENTAL SCIENCES.csv',
#  'ENVIRONMENTAL STUDIES.csv',
#  'ERGONOMICS.csv',
#  'ETHICS.csv',
#  'ETHNIC STUDIES.csv',
#  'EVOLUTIONARY BIOLOGY.csv',
#  'FAMILY STUDIES.csv',
#  'FISHERIES.csv',
#  'FOOD SCIENCE & TECHNOLOGY.csv',
#  'FORESTRY.csv',
#  'GASTROENTEROLOGY & HEPATOLOGY.csv',
#  'GENETICS & HEREDITY.csv',
#  'GEOCHEMISTRY & GEOPHYSICS.csv',
#  'GEOGRAPHY, PHYSICAL.csv',
#  'GEOGRAPHY.csv',
#  'GEOLOGY.csv',
#  'GEOSCIENCES, MULTIDISCIPLINARY.csv',
#  'GERIATRICS & GERONTOLOGY.csv',
#  'GERONTOLOGY.csv',
#  'GREEN & SUSTAINABLE SCIENCE & TECHNOLOGY.csv',
#  'HEALTH CARE SCIENCES & SERVICES.csv',
#  'HEALTH POLICY & SERVICES.csv',
#  'HEMATOLOGY.csv',
#  'HISTORY & PHILOSOPHY OF SCIENCE.csv',
#  'HISTORY OF SOCIAL SCIENCES.csv',
#  'HISTORY.csv',
#  'HORTICULTURE.csv',
#  'HOSPITALITY, LEISURE, SPORT & TOURISM.csv',
#  'IMAGING SCIENCE & PHOTOGRAPHIC TECHNOLOGY.csv',
#  'IMMUNOLOGY.csv',
#  'INDUSTRIAL RELATIONS & LABOR.csv',
#  'INFECTIOUS DISEASES.csv',
#  'INFORMATION SCIENCE & LIBRARY SCIENCE.csv',
#  'INSTRUMENTS & INSTRUMENTATION.csv',
#  'INTEGRATIVE & COMPLEMENTARY MEDICINE.csv',
#  'INTERNATIONAL RELATIONS.csv',
#  'LAW.csv',
#  'LIMNOLOGY.csv',
#  'LINGUISTICS.csv',
#  'LOGIC.csv',
#  'MANAGEMENT.csv',
#  'MARINE & FRESHWATER BIOLOGY.csv',
#  'MATERIALS SCIENCE, BIOMATERIALS.csv',
#  'MATERIALS SCIENCE, CERAMICS.csv',
#  'MATERIALS SCIENCE, CHARACTERIZATION & TESTING.csv',
#  'MATERIALS SCIENCE, COATINGS & FILMS.csv',
#  'MATERIALS SCIENCE, COMPOSITES.csv',
#  'MATERIALS SCIENCE, MULTIDISCIPLINARY.csv',
#  'MATERIALS SCIENCE, PAPER & WOOD.csv',
#  'MATERIALS SCIENCE, TEXTILES.csv',
#  'MATHEMATICAL & COMPUTATIONAL BIOLOGY.csv',
#  'MATHEMATICS, APPLIED.csv',
#  'MATHEMATICS, INTERDISCIPLINARY APPLICATIONS.csv',
#  'MATHEMATICS.csv',
#  'MECHANICS.csv',
#  'MEDICAL ETHICS.csv',
#  'MEDICAL INFORMATICS.csv',
#  'MEDICAL LABORATORY TECHNOLOGY.csv',
#  'MEDICINE, GENERAL & INTERNAL.csv',
#  'MEDICINE, LEGAL.csv',
#  'MEDICINE, RESEARCH & EXPERIMENTAL.csv',
#  'METALLURGY & METALLURGICAL ENGINEERING.csv',
#  'METEOROLOGY & ATMOSPHERIC SCIENCES.csv',
#  'MICROBIOLOGY.csv',
#  'MICROSCOPY.csv',
#  'MINERALOGY.csv',
#  'MINING & MINERAL PROCESSING.csv',
#  'MULTIDISCIPLINARY SCIENCES.csv',
#  'MYCOLOGY.csv',
#  'NANOSCIENCE & NANOTECHNOLOGY.csv',
#  'NEUROIMAGING.csv',
#  'NEUROSCIENCES.csv',
#  'NUCLEAR SCIENCE & TECHNOLOGY.csv',
#  'NURSING.csv',
#  'NUTRITION & DIETETICS.csv',
#  'OBSTETRICS & GYNECOLOGY.csv',
#  'OCEANOGRAPHY.csv',
#  'ONCOLOGY.csv',
#  'OPERATIONS RESEARCH & MANAGEMENT SCIENCE.csv',
#  'OPHTHALMOLOGY.csv',
#  'OPTICS.csv',
#  'ORNITHOLOGY.csv',
#  'ORTHOPEDICS.csv',
#  'OTORHINOLARYNGOLOGY.csv',
#  'PALEONTOLOGY.csv',
#  'PARASITOLOGY.csv',
#  'PATHOLOGY.csv',
#  'PEDIATRICS.csv',
#  'PERIPHERAL VASCULAR DISEASE.csv',
#  'PHARMACOLOGY & PHARMACY.csv',
#  'PHYSICS, APPLIED.csv',
#  'PHYSICS, ATOMIC, MOLECULAR & CHEMICAL.csv',
#  'PHYSICS, CONDENSED MATTER.csv',
#  'PHYSICS, FLUIDS & PLASMAS.csv',
#  'PHYSICS, MATHEMATICAL.csv',
#  'PHYSICS, MULTIDISCIPLINARY.csv',
#  'PHYSICS, NUCLEAR.csv',
#  'PHYSICS, PARTICLES & FIELDS.csv',
#  'PHYSIOLOGY.csv',
#  'PLANNING & DEVELOPMENT.csv',
#  'PLANT SCIENCES.csv',
#  'POLITICAL SCIENCE.csv',
#  'POLYMER SCIENCE.csv',
#  'PRIMARY HEALTH CARE.csv',
#  'PSYCHIATRY.csv',
#  'PSYCHOLOGY, APPLIED.csv',
#  'PSYCHOLOGY, BIOLOGICAL.csv',
#  'PSYCHOLOGY, CLINICAL.csv',
#  'PSYCHOLOGY, DEVELOPMENTAL.csv',
#  'PSYCHOLOGY, EDUCATIONAL.csv',
#  'PSYCHOLOGY, EXPERIMENTAL.csv',
#  'PSYCHOLOGY, MATHEMATICAL.csv',
#  'PSYCHOLOGY, MULTIDISCIPLINARY.csv',
#  'PSYCHOLOGY, PSYCHOANALYSIS.csv',
#  'PSYCHOLOGY, SOCIAL.csv',
#  'PSYCHOLOGY.csv',
#  'PUBLIC ADMINISTRATION.csv',
#  'PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH.csv',
#  'RADIOLOGY, NUCLEAR MEDICINE & MEDICAL IMAGING.csv',
#  'REHABILITATION.csv',
#  'REMOTE SENSING.csv',
#  'REPRODUCTIVE BIOLOGY.csv',
#  'RESPIRATORY SYSTEM.csv',
#  'RHEUMATOLOGY.csv',
#  'ROBOTICS.csv',
#  'SOCIAL ISSUES.csv',
#  'SOCIAL SCIENCES, BIOMEDICAL.csv',
#  'SOCIAL SCIENCES, INTERDISCIPLINARY.csv',
#  'SOCIAL SCIENCES, MATHEMATICAL METHODS.csv',
#  'SOCIAL WORK.csv',
#  'SOCIOLOGY.csv',
#  'SOIL SCIENCE.csv',
#  'SPECTROSCOPY.csv',
#  'SPORT SCIENCES.csv',
#  'STATISTICS & PROBABILITY.csv',
#  'SUBSTANCE ABUSE.csv',
#  'SURGERY.csv',
#  'TELECOMMUNICATIONS.csv',
#  'THERMODYNAMICS.csv',
#  'TOXICOLOGY.csv',
#  'TRANSPLANTATION.csv',
#  'TRANSPORTATION SCIENCE & TECHNOLOGY.csv',
#  'TRANSPORTATION.csv',
#  'TROPICAL MEDICINE.csv',
#  'URBAN STUDIES.csv',
#  'UROLOGY & NEPHROLOGY.csv',
#  'VETERINARY SCIENCES.csv',
#  'VIROLOGY.csv',
#  'WATER RESOURCES.csv',
#  'WOMENS STUDIES.csv',
#  'ZOOLOGY.csv']

# %%
#读入csv中的数据，（导入检索式）
a = []
csv_reader=csv.reader(open(Folder_Path +'\\'+ file_list[0]))#打开第一个文件
for row in csv_reader:
    a.append(row)#将读入的数据赋值给列表a

# %%
############首先对Mapp.csv原文件数据去重，删除数据重复的项目######################
lis_a = []#创建空白列表，存储文件内容
csv_reader=csv.reader(open(r'C:\Users\rk\Desktop\Mapp.csv'))

# %%
for element in csv_reader:
    lis_a.append(element)#逐行读入数据，写入列表

# %%
#lis_a

# %%
####################运用此程序的前提是：先在原文件里做好分类汇总####################################
final_lis=[]
counter=0
while True:#为了是for循环中的起始值counter的改变，for进入循环后，起始值不再改变，
    for item_1 in lis_a[counter:]:
        diction=[]
        lis_c=[]
        initial_s=0
        lis_c.append(item_1[1])#将第一个期刊加入列表，在此处加入是防止仅出现一次而忽略
        for item_2 in lis_a[counter+1:]:
            if item_1[0]==item_2[0]:
                lis_c.append(item_2[1])#将相同的期刊加入列表
                initial_s+=1 #每找到一个相同的就把initial_s加一，     
        diction.append(item_1[0])
        diction.append(lis_c)
        final_lis.append(diction)
        break#为了使for循环中的起始值改变，循环一次后利用break强制退出for循环，利用while进入下一次循环
    counter=counter+initial_s+1
    if counter>=len(lis_a):#为了使while循环跳出,当大于列表长度的时候跳出循环
        break

# %%
final_lis
# Out:
# [['数学', ['Mathematics', 'Mathematics, Applied']],
#  ['物理学',
#   ['Acoustics',
#    'Astronomy & Astrophysics',
#    'Optics',
#    'Physics, Applied',
#    'Physics, Atomic, Molecular & Chemical',
#    'Physics, Condensed Matter',
#    'Physics, Fluids & Plasmas',
#    'Physics, Mathematical',
#    'Physics, Multidisciplinary',
#    'Physics, Nuclear',
#    'Physics, Particles & Fields']],
#  ['化学',
#   ['Chemistry, Analytical',
#    'Chemistry, Applied',
#    'Chemistry, Inorganic & Nuclear',
#    'Chemistry, Multidisciplinary',
#    'Chemistry, Organic',
#    'Chemistry, Physical',
#    'Crystallography',
#    'Electrochemistry',
#    'Spectroscopy',
#    'Polymer Science']],
#  ['地球科学',
#   ['Geochemistry & Geophysics',
#    'Geology',
#    'Geosciences, Multidisciplinary',
#    'Mineralogy',
#    'Paleontology']],
#  ['地理学', ['Area Studies', 'Geography', 'Geography, Physical']],
#  ['生态学', ['Biodiversity Conservation', 'Ecology']],
#  ['海洋科学', ['Oceanography']],
#  ['大气科学', ['Meteorology & Atmospheric Sciences']],
#  ['机械工程', ['Engineering, Manufacturing', 'Engineering, Mechanical']],
#  ['电力电子工程',
#   ['Engineering, Electrical & Electronic',
#    'Imaging Science & Photographic Technology']],
#  ['控制科学与工程', ['Automation & Control Systems', 'Robotics']],
#  ['通信工程', ['Telecommunications']],
#  ['仪器科学', ['Instruments & Instrumentation', 'Microscopy']],
#  ['生物医学工程', ['Cell & Tissue Engineering', 'Engineering, Biomedical']],
#  ['计算机科学与工程',
#   ['Computer Science, Information Systems',
#    'Computer Science, Cybernetics',
#    'Computer Science, Software Engineering',
#    'Computer Science, Artificial Intelligence',
#    'Computer Science, Hardware & Architecture',
#    'Computer Science, Theory & Methods',
#    'Computer Science, Interdisciplinary Applications']],
#  ['土木工程', ['Construction & Building Technology', 'Engineering, Civil']],
#  ['化学工程', ['Engineering, Chemical']],
#  ['材料科学与工程',
#   ['Materials Science, Biomaterials',
#    'Materials Science, Ceramics',
#    'Materials Science, Characterization & Testing',
#    'Materials Science, Coatings & Films',
#    'Materials Science, Composites',
#    'Materials Science, Multidisciplinary',
#    'Materials Science, Paper & Wood',
#    'Materials Science, Textiles']],
#  ['纳米科学与技术', ['Nanoscience & Nanotechnology']],
#  ['能源科学与工程',
#   ['Energy & Fuels',
#    'Nuclear Science & Technology',
#    'Engineering, Petroleum']],
#  ['环境科学与工程',
#   ['Engineering, Environmental',
#    'Environmental Sciences',
#    'Environmental Studies']],
#  ['水资源工程', ['Water Resources']],
#  ['农业工程', ['Agricultural Engineering']],
#  ['食品科学与工程', ['Food Science & Technology']],
#  ['生物工程', ['Biotechnology & Applied Microbiology']],
#  ['航空航天工程', ['Engineering, Aerospace']],
#  ['船舶与海洋工程', ['Engineering, Marine', 'Engineering, Ocean']],
#  ['交通运输工程', ['Transportation', 'Transportation Science & Technology']],
#  ['遥感技术', ['Remote Sensing']],
#  ['地质工程', ['Engineering, Geological']],
#  ['矿业工程', ['Mining & Mineral Processing']],
#  ['冶金工程', ['Metallurgy & Metallurgical Engineering']],
#  ['生物学',
#   ['Biochemical Research Methods',
#    'Biochemistry & Molecular Biology',
#    'Biology',
#    'Biophysics',
#    'Cell Biology',
#    'Developmental Biology',
#    'Entomology',
#    'Evolutionary Biology',
#    'Genetics & Heredity',
#    'Limnology',
#    'Marine & Freshwater Biology',
#    'Mathematical & Computational Biology',
#    'Microbiology',
#    'Mycology',
#    'Ornithology',
#    'Physiology',
#    'Reproductive Biology',
#    'Virology',
#    'Zoology']],
#  ['基础医学',
#   ['Neurosciences',
#    'Anatomy & Morphology',
#    'Parasitology',
#    'Pathology',
#    'Immunology',
#    'Medical Informatics',
#    'Medicine, Research & Experimental']],
#  ['农学',
#   ['Agronomy',
#    'Horticulture',
#    'Fisheries',
#    'Soil Science',
#    'Forestry',
#    'Agriculture, Dairy & Animal Science',
#    'Agriculture, Multidisciplinary',
#    'Plant Sciences']],
#  ['兽医学', ['Veterinary Sciences']],
#  ['临床医学',
#   ['Allergy',
#    'Andrology',
#    'Anesthesiology',
#    'Cardiac & Cardiovascular Systems',
#    'Clinical Neurology',
#    'Critical Care Medicine',
#    'Dermatology',
#    'Emergency Medicine',
#    'Endocrinology & Metabolism',
#    'Gastroenterology & Hepatology',
#    'Geriatrics & Gerontology',
#    'Gerontology',
#    'Hematology',
#    'Integrative & Complementary Medicine',
#    'Medicine, General & Internal',
#    'Obstetrics & Gynecology',
#    'Oncology',
#    'Ophthalmology',
#    'Orthopedics',
#    'Otorhinolaryngology',
#    'Pediatrics',
#    'Peripheral Vascular Disease',
#    'Psychiatry',
#    'Rehabilitation',
#    'Respiratory System',
#    'Rheumatology',
#    'Surgery',
#    'Transplantation',
#    'Tropical Medicine',
#    'Urology & Nephrology',
#    'Audiology & Speech-Language Pathology']],
#  ['公共卫生',
#   ['Health Policy & Services',
#    'Health Care Sciences & Services',
#    'Infectious Diseases',
#    'Nutrition & Dietetics',
#    'Primary Health Care',
#    'Public, Environmental & Occupational Health',
#    'Social Sciences, Biomedical',
#    'Substance Abuse',
#    'Ergonomics']],
#  ['口腔医学', ['Dentistry, Oral Surgery & Medicine']],
#  ['护理学', ['Nursing']],
#  ['医学技术',
#   ['Medical Laboratory Technology',
#    'Neuroimaging',
#    'Radiology, Nuclear Medicine & Medical Imaging']],
#  ['药学', ['Chemistry, Medicinal', 'Pharmacology & Pharmacy', 'Toxicology']],
#  ['经济学', ['Economics']],
#  ['统计学', ['Statistics & Probability']],
#  ['法学', ['Criminology & Penology', 'Law']],
#  ['政治学', ['International Relations', 'Political Science']],
#  ['社会学', ['Sociology']],
#  ['教育学',
#   ['Education & Educational Research',
#    'Education, Scientific Disciplines',
#    'Education, Special']],
#  ['新闻传播学', ['Communication']],
#  ['心理学',
#   ['Psychology',
#    'Psychology, Applied',
#    'Psychology, Biological',
#    'Psychology, Clinical',
#    'Psychology, Developmental',
#    'Psychology, Educational',
#    'Psychology, Experimental',
#    'Psychology, Mathematical',
#    'Psychology, Multidisciplinary',
#    'Psychology, Psychoanalysis',
#    'Psychology, Social',
#    'Behavioral Sciences']],
#  ['工商管理', ['Business', 'Industrial Relations & Labor']],
#  ['金融学', ['Business, Finance']],
#  ['管理学', ['Management', 'Operations Research & Management Science']],
#  ['公共管理', ['Public Administration']],
#  ['旅游休闲管理', ['Hospitality, Leisure, Sport & Tourism']],
#  ['农林经济管理', ['Agricultural Economics & Policy']],
#  ['图书情报科学', ['Information Science & Library Science']]]

# %%
final_lis[1]
# Out:
# ['物理学',
#  ['Acoustics',
#   'Astronomy & Astrophysics',
#   'Optics',
#   'Physics, Applied',
#   'Physics, Atomic, Molecular & Chemical',
#   'Physics, Condensed Matter',
#   'Physics, Fluids & Plasmas',
#   'Physics, Mathematical',
#   'Physics, Multidisciplinary',
#   'Physics, Nuclear',
#   'Physics, Particles & Fields']]

# %%
final_lis[1][1]
# Out:
# ['Acoustics',
#  'Astronomy & Astrophysics',
#  'Optics',
#  'Physics, Applied',
#  'Physics, Atomic, Molecular & Chemical',
#  'Physics, Condensed Matter',
#  'Physics, Fluids & Plasmas',
#  'Physics, Mathematical',
#  'Physics, Multidisciplinary',
#  'Physics, Nuclear',
#  'Physics, Particles & Fields']

# %%
savefilename=final_lis[0]

# %%
coun=counter=0
for final_li in final_lis:
    savefilename=final_li[0]
    flag=0
    lis_name=[]#创建空白列表
    lis_name.append(['Rank','Full Journal Title','ISSN','Total Cites','Journal Impact Factor','Eigenfactor Score','category'])
    #print(lis_name)
    #counter+=1
    for file_lis in file_list:#循环处理过的软科-WOS映射表
        category=file_lis[:file_lis.find('.')]#截取WOS学科分类名
        category=category.lower()#将WOS学科分类名全部小写
        ele=[]#创建空白列表
        for element in final_li[1]:#循环软科分类下的WOS学科分类，使其全部小写
            ele.append(element.lower())
        final_li[1]=ele #全部小写的重新赋值给final_li[1]  
        if category in final_li[1]:#判断WOS学科分类是否在软科-WOS映射表中
            #print(1)
            flag=1
            e=[]
            csv_reader=csv.reader(open(Folder_Path +'\\'+ file_lis))
            for row in csv_reader:
                e.append(row)#将读入的数据赋值给列表
            for item in e[2:-2]:
                item.append(savefilename)#将软科学科分类名字添加到最后一列
                lis_name.append(item)
    if flag==1:    
        result=pd.DataFrame(np.array(lis_name))#将pd.DataFrame(np.array(myarray))写入list
        result.to_csv("C:/Users/rk/Desktop/result"+"/"+ savefilename+".csv",index=False,encoding='ANSI')#按照软科学科分类导出文件

# %%
lis_name
# Out:
# [['Rank',
#   'Full Journal Title',
#   'ISSN',
#   'Total Cites',
#   'Journal Impact Factor',
#   'Eigenfactor Score',
#   'category'],
#  ['1', 'MIS QUARTERLY', '0276-7783', '14,561', '7.268', '0.012460', '图书情报科学'],
#  ['2',
#   'JOURNAL OF INFORMATION TECHNOLOGY',
#   '0268-3962',
#   '2,515',
#   '6.953',
#   '0.002840',
#   '图书情报科学'],
#  ['3',
#   'INFORMATION SYSTEMS JOURNAL',
#   '1350-1917',
#   '1,416',
#   '4.122',
#   '0.001470',
#   '图书情报科学'],
#  ['4',
#   'Journal of Computer-Mediated Communication',
#   '1083-6101',
#   '4,011',
#   '4.113',
#   '0.005000',
#   '图书情报科学'],
#  ['5',
#   'GOVERNMENT INFORMATION QUARTERLY',
#   '0740-624X',
#   '2,719',
#   '4.090',
#   '0.002950',
#   '图书情报科学'],
#  ['6',
#   'INTERNATIONAL JOURNAL OF INFORMATION MANAGEMENT',
#   '0268-4012',
#   '3,087',
#   '3.872',
#   '0.003760',
#   '图书情报科学'],
#  ['7',
#   'JOURNAL OF THE AMERICAN MEDICAL INFORMATICS ASSOCIATION',
#   '1067-5027',
#   '7,655',
#   '3.698',
#   '0.017230',
#   '图书情报科学'],
#  ['8',
#   'JOURNAL OF STRATEGIC INFORMATION SYSTEMS',
#   '0963-8687',
#   '1,580',
#   '3.486',
#   '0.001310',
#   '图书情报科学'],
#  ['9',
#   'International Journal of Computer-Supported Collaborative Learning',
#   '1556-1607',
#   '656',
#   '3.469',
#   '0.000930',
#   '图书情报科学'],
#  ['10',
#   'TELEMATICS AND INFORMATICS',
#   '0736-5853',
#   '1,104',
#   '3.398',
#   '0.001820',
#   '图书情报科学'],
#  ['11',
#   'INFORMATION & MANAGEMENT',
#   '0378-7206',
#   '5,783',
#   '3.317',
#   '0.003600',
#   '图书情报科学'],
#  ['12',
#   'Journal of Informetrics',
#   '1751-1577',
#   '2,067',
#   '2.920',
#   '0.004730',
#   '图书情报科学'],
#  ['13',
#   'EUROPEAN JOURNAL OF INFORMATION SYSTEMS',
#   '0960-085X',
#   '2,395',
#   '2.819',
#   '0.002210',
#   '图书情报科学'],
#  ['14',
#   'INFORMATION SYSTEMS RESEARCH',
#   '1047-7047',
#   '6,257',
#   '2.763',
#   '0.007320',
#   '图书情报科学'],
#  ['15',
#   'INTERNATIONAL JOURNAL OF GEOGRAPHICAL INFORMATION SCIENCE',
#   '1365-8816',
#   '4,276',
#   '2.502',
#   '0.004810',
#   '图书情报科学'],
#  ['16',
#   'INFORMATION PROCESSING & MANAGEMENT',
#   '0306-4573',
#   '3,067',
#   '2.391',
#   '0.002830',
#   '图书情报科学'],
#  ['17',
#   'JOURNAL OF MANAGEMENT INFORMATION SYSTEMS',
#   '0742-1222',
#   '4,456',
#   '2.356',
#   '0.002890',
#   '图书情报科学'],
#  ['18',
#   'Journal of the Association for Information Science and Technology',
#   '2330-1635',
#   '978',
#   '2.322',
#   '0.003540',
#   '图书情报科学'],
#  ['19',
#   'RESEARCH EVALUATION',
#   '0958-2029',
#   '919',
#   '2.312',
#   '0.001590',
#   '图书情报科学'],
#  ['20',
#   'SOCIAL SCIENCE COMPUTER REVIEW',
#   '0894-4393',
#   '1,263',
#   '2.293',
#   '0.002600',
#   '图书情报科学'],
#  ['21', 'SCIENTOMETRICS', '0138-9130', '7,831', '2.147', '0.010780', '图书情报科学'],
#  ['22',
#   'Journal of the Association for Information Systems',
#   '1536-9323',
#   '1,702',
#   '2.109',
#   '0.002240',
#   '图书情报科学'],
#  ['23',
#   'Information and Organization',
#   '1471-7727',
#   '515',
#   '2.083',
#   '0.000800',
#   '图书情报科学'],
#  ['24',
#   'Journal of Knowledge Management',
#   '1367-3270',
#   '2,774',
#   '2.053',
#   '0.001470',
#   '图书情报科学'],
#  ['25',
#   'QUALITATIVE HEALTH RESEARCH',
#   '1049-7323',
#   '6,733',
#   '2.036',
#   '0.007160',
#   '图书情报科学'],
#  ['26',
#   'MIS Quarterly Executive',
#   '1540-1960',
#   '483',
#   '1.741',
#   '0.000670',
#   '图书情报科学'],
#  ['27',
#   'Information Development',
#   '0266-6669',
#   '319',
#   '1.691',
#   '0.000450',
#   '图书情报科学'],
#  ['28',
#   'JOURNAL OF THE MEDICAL LIBRARY ASSOCIATION',
#   '1536-5050',
#   '829',
#   '1.638',
#   '0.000960',
#   '图书情报科学'],
#  ['29',
#   'JOURNAL OF HEALTH COMMUNICATION',
#   '1081-0730',
#   '3,233',
#   '1.614',
#   '0.007070',
#   '图书情报科学'],
#  ['30',
#   'INFORMATION SOCIETY',
#   '0197-2243',
#   '1,042',
#   '1.558',
#   '0.000750',
#   '图书情报科学'],
#  ['31',
#   'ONLINE INFORMATION REVIEW',
#   '1468-4527',
#   '1,042',
#   '1.534',
#   '0.001160',
#   '图书情报科学'],
#  ['32',
#   'TELECOMMUNICATIONS POLICY',
#   '0308-5961',
#   '1,509',
#   '1.526',
#   '0.002270',
#   '图书情报科学'],
#  ['33',
#   'COLLEGE & RESEARCH LIBRARIES',
#   '0010-0870',
#   '977',
#   '1.515',
#   '0.001240',
#   '图书情报科学'],
#  ['34',
#   'Aslib Journal of Information Management',
#   '2050-3806',
#   '118',
#   '1.514',
#   '0.000340',
#   '图书情报科学'],
#  ['35',
#   'Ethics and Information Technology',
#   '1388-1957',
#   '569',
#   '1.500',
#   '0.000530',
#   '图书情报科学'],
#  ['36',
#   'JOURNAL OF INFORMATION SCIENCE',
#   '0165-5515',
#   '1,585',
#   '1.372',
#   '0.001560',
#   '图书情报科学'],
#  ['37',
#   'Information Technology & People',
#   '0959-3845',
#   '642',
#   '1.339',
#   '0.000510',
#   '图书情报科学'],
#  ['38',
#   'Information Technology for Development',
#   '0268-1102',
#   '382',
#   '1.333',
#   '0.000480',
#   '图书情报科学'],
#  ['38',
#   'LEARNED PUBLISHING',
#   '0953-1513',
#   '322',
#   '1.333',
#   '0.000700',
#   '图书情报科学'],
#  ['40',
#   'PORTAL-LIBRARIES AND THE ACADEMY',
#   '1531-2542',
#   '445',
#   '1.290',
#   '0.000880',
#   '图书情报科学'],
#  ['41',
#   'JOURNAL OF ACADEMIC LIBRARIANSHIP',
#   '0099-1333',
#   '1,241',
#   '1.287',
#   '0.001360',
#   '图书情报科学'],
#  ['42',
#   'LIBRARY & INFORMATION SCIENCE RESEARCH',
#   '0740-8188',
#   '962',
#   '1.185',
#   '0.001160',
#   '图书情报科学'],
#  ['43',
#   'Journal of Global Information Technology Management',
#   '1097-198X',
#   '228',
#   '1.167',
#   '0.000160',
#   '图书情报科学'],
#  ['44',
#   'Information Technology & Management',
#   '1385-951X',
#   '281',
#   '1.067',
#   '0.000420',
#   '图书情报科学'],
#  ['45',
#   'Profesional de la Informacion',
#   '1386-6710',
#   '466',
#   '1.063',
#   '0.000450',
#   '图书情报科学'],
#  ['46',
#   'INFORMATION TECHNOLOGY AND LIBRARIES',
#   '0730-9295',
#   '260',
#   '1.029',
#   '0.000390',
#   '图书情报科学'],
#  ['47',
#   'JOURNAL OF LIBRARIANSHIP AND INFORMATION SCIENCE',
#   '0961-0006',
#   '352',
#   '1.019',
#   '0.000580',
#   '图书情报科学'],
#  ['48',
#   'Knowledge Management Research & Practice',
#   '1477-8238',
#   '540',
#   '1.013',
#   '0.000480',
#   '图书情报科学'],
#  ['49',
#   'Health Information and Libraries Journal',
#   '1471-1834',
#   '663',
#   '0.875',
#   '0.000710',
#   '图书情报科学'],
#  ['50',
#   'JOURNAL OF DOCUMENTATION',
#   '0022-0418',
#   '1,497',
#   '0.853',
#   '0.001040',
#   '图书情报科学'],
#  ['51',
#   'KNOWLEDGE ORGANIZATION',
#   '0943-7444',
#   '297',
#   '0.831',
#   '0.000140',
#   '图书情报科学'],
#  ['52',
#   'Journal of Organizational and End User Computing',
#   '1546-2234',
#   '138',
#   '0.759',
#   '0.000050',
#   '图书情报科学'],
#  ['52', 'LIBRARY HI TECH', '0737-8831', '454', '0.759', '0.000720', '图书情报科学'],
#  ['54',
#   'Revista Espanola de Documentacion Cientifica',
#   '0210-0614',
#   '248',
#   '0.746',
#   '0.000260',
#   '图书情报科学'],
#  ['55',
#   'Malaysian Journal of Library & Information Science',
#   '1394-6234',
#   '134',
#   '0.650',
#   '0.000240',
#   '图书情报科学'],
#  ['56',
#   'Australian Academic & Research Libraries',
#   '0004-8623',
#   '177',
#   '0.647',
#   '0.000300',
#   '图书情报科学'],
#  ['57',
#   'INFORMATION RESEARCH-AN INTERNATIONAL ELECTRONIC JOURNAL',
#   '1368-1613',
#   '732',
#   '0.574',
#   '0.000900',
#   '图书情报科学'],
#  ['58',
#   'LIBRARY QUARTERLY',
#   '0024-2519',
#   '474',
#   '0.558',
#   '0.000480',
#   '图书情报科学'],
#  ['59',
#   'PROGRAM-ELECTRONIC LIBRARY AND INFORMATION SYSTEMS',
#   '0033-0337',
#   '330',
#   '0.556',
#   '0.000370',
#   '图书情报科学'],
#  ['60',
#   'LAW LIBRARY JOURNAL',
#   '0023-9283',
#   '283',
#   '0.540',
#   '0.000110',
#   '图书情报科学'],
#  ['61',
#   'Journal of Global Information Management',
#   '1062-7375',
#   '319',
#   '0.517',
#   '0.000130',
#   '图书情报科学'],
#  ['62',
#   'SOCIAL SCIENCE INFORMATION SUR LES SCIENCES SOCIALES',
#   '0539-0184',
#   '862',
#   '0.490',
#   '0.000570',
#   '图书情报科学'],
#  ['63',
#   'ELECTRONIC LIBRARY',
#   '0264-0473',
#   '382',
#   '0.484',
#   '0.000430',
#   '图书情报科学'],
#  ['63',
#   'LIBRARY RESOURCES & TECHNICAL SERVICES',
#   '0024-2527',
#   '165',
#   '0.484',
#   '0.000160',
#   '图书情报科学'],
#  ['65',
#   'JOURNAL OF SCHOLARLY PUBLISHING',
#   '1198-9742',
#   '100',
#   '0.472',
#   '0.000120',
#   '图书情报科学'],
#  ['66',
#   'DATA BASE FOR ADVANCES IN INFORMATION SYSTEMS',
#   '0095-0033',
#   '585',
#   '0.458',
#   '0.000240',
#   '图书情报科学'],
#  ['67', 'LIBRI', '0024-2667', '213', '0.400', '0.000280', '图书情报科学'],
#  ['68', 'SERIALS REVIEW', '0098-7913', '184', '0.379', '0.000350', '图书情报科学'],
#  ['69',
#   'RESTAURATOR-INTERNATIONAL JOURNAL FOR THE PRESERVATION OF LIBRARY AND ARCHIVAL MATERIAL',
#   '0034-5806',
#   '196',
#   '0.367',
#   '0.000090',
#   '图书情报科学'],
#  ['70',
#   'Information & Culture',
#   '2164-8034',
#   '59',
#   '0.364',
#   '0.000180',
#   '图书情报科学'],
#  ['70',
#   'LIBRARY AND INFORMATION SCIENCE',
#   '0373-4447',
#   '29',
#   '0.364',
#   '0.000030',
#   '图书情报科学'],
#  ['72', 'Transinformacao', '0103-3786', '60', '0.352', '0.000080', '图书情报科学'],
#  ['73',
#   'REFERENCE & USER SERVICES QUARTERLY',
#   '1094-9054',
#   '261',
#   '0.339',
#   '0.000240',
#   '图书情报科学'],
#  ['74', 'SCIENTIST', '0890-3670', '236', '0.325', '0.000300', '图书情报科学'],
#  ['75', 'LIBRARY TRENDS', '0024-2594', '663', '0.259', '0.000650', '图书情报科学'],
#  ['76',
#   'Australian Library Journal',
#   '0004-9670',
#   '103',
#   '0.255',
#   '0.000190',
#   '图书情报科学'],
#  ['77',
#   'LIBRARY COLLECTIONS ACQUISITIONS & TECHNICAL SERVICES',
#   '1464-9055',
#   '149',
#   '0.200',
#   '0.000110',
#   '图书情报科学'],
#  ['78',
#   'African Journal of Library Archives and Information Science',
#   '0795-4778',
#   '48',
#   '0.179',
#   '0.000020',
#   '图书情报科学'],
#  ['79',
#   'INTERLENDING & DOCUMENT SUPPLY',
#   '0264-1615',
#   '80',
#   '0.175',
#   '0.000030',
#   '图书情报科学'],
#  ['80',
#   'ZEITSCHRIFT FUR BIBLIOTHEKSWESEN UND BIBLIOGRAPHIE',
#   '0044-2380',
#   '31',
#   '0.158',
#   '0.000010',
#   '图书情报科学'],
#  ['81',
#   'Investigacion Bibliotecologica',
#   '0187-358X',
#   '65',
#   '0.125',
#   '0.000040',
#   '图书情报科学'],
#  ['82',
#   'CANADIAN JOURNAL OF INFORMATION AND LIBRARY SCIENCE-REVUE CANADIENNE DES SCIENCES DE L INFORMATION ET DE BIBLIOTHECONOMIE',
#   '1195-096X',
#   '57',
#   '0.111',
#   '0.000030',
#   '图书情报科学'],
#  ['83',
#   'Informacao & Sociedade-Estudos',
#   '0104-0146',
#   '54',
#   '0.086',
#   '0.000040',
#   '图书情报科学'],
#  ['84', 'ECONTENT', '1525-2531', '17', '0.025', '0.000020', '图书情报科学'],
#  ['85',
#   'Informacios Tarsadalom',
#   '1587-8694',
#   '4',
#   '0.022',
#   '0.000000',
#   '图书情报科学']]

# %%
np.array(lis_name)
# Out:
# array([['Rank', 'Full Journal Title', 'ISSN', 'Total Cites',
#         'Journal Impact Factor', 'Eigenfactor Score', 'category'],
#        ['1', 'MIS QUARTERLY', '0276-7783', '14,561', '7.268', '0.012460',
#         '图书情报科学'],
#        ['2', 'JOURNAL OF INFORMATION TECHNOLOGY', '0268-3962', '2,515',
#         '6.953', '0.002840', '图书情报科学'],
#        ['3', 'INFORMATION SYSTEMS JOURNAL', '1350-1917', '1,416',
#         '4.122', '0.001470', '图书情报科学'],
#        ['4', 'Journal of Computer-Mediated Communication', '1083-6101',
#         '4,011', '4.113', '0.005000', '图书情报科学'],
#        ['5', 'GOVERNMENT INFORMATION QUARTERLY', '0740-624X', '2,719',
#         '4.090', '0.002950', '图书情报科学'],
#        ['6', 'INTERNATIONAL JOURNAL OF INFORMATION MANAGEMENT',
#         '0268-4012', '3,087', '3.872', '0.003760', '图书情报科学'],
#        ['7', 'JOURNAL OF THE AMERICAN MEDICAL INFORMATICS ASSOCIATION',
#         '1067-5027', '7,655', '3.698', '0.017230', '图书情报科学'],
#        ['8', 'JOURNAL OF STRATEGIC INFORMATION SYSTEMS', '0963-8687',
#         '1,580', '3.486', '0.001310', '图书情报科学'],
#        ['9',
#         'International Journal of Computer-Supported Collaborative Learning',
#         '1556-1607', '656', '3.469', '0.000930', '图书情报科学'],
#        ['10', 'TELEMATICS AND INFORMATICS', '0736-5853', '1,104',
#         '3.398', '0.001820', '图书情报科学'],
#        ['11', 'INFORMATION & MANAGEMENT', '0378-7206', '5,783', '3.317',
#         '0.003600', '图书情报科学'],
#        ['12', 'Journal of Informetrics', '1751-1577', '2,067', '2.920',
#         '0.004730', '图书情报科学'],
#        ['13', 'EUROPEAN JOURNAL OF INFORMATION SYSTEMS', '0960-085X',
#         '2,395', '2.819', '0.002210', '图书情报科学'],
#        ['14', 'INFORMATION SYSTEMS RESEARCH', '1047-7047', '6,257',
#         '2.763', '0.007320', '图书情报科学'],
#        ['15',
#         'INTERNATIONAL JOURNAL OF GEOGRAPHICAL INFORMATION SCIENCE',
#         '1365-8816', '4,276', '2.502', '0.004810', '图书情报科学'],
#        ['16', 'INFORMATION PROCESSING & MANAGEMENT', '0306-4573',
#         '3,067', '2.391', '0.002830', '图书情报科学'],
#        ['17', 'JOURNAL OF MANAGEMENT INFORMATION SYSTEMS', '0742-1222',
#         '4,456', '2.356', '0.002890', '图书情报科学'],
#        ['18',
#         'Journal of the Association for Information Science and Technology',
#         '2330-1635', '978', '2.322', '0.003540', '图书情报科学'],
#        ['19', 'RESEARCH EVALUATION', '0958-2029', '919', '2.312',
#         '0.001590', '图书情报科学'],
#        ['20', 'SOCIAL SCIENCE COMPUTER REVIEW', '0894-4393', '1,263',
#         '2.293', '0.002600', '图书情报科学'],
#        ['21', 'SCIENTOMETRICS', '0138-9130', '7,831', '2.147',
#         '0.010780', '图书情报科学'],
#        ['22', 'Journal of the Association for Information Systems',
#         '1536-9323', '1,702', '2.109', '0.002240', '图书情报科学'],
#        ['23', 'Information and Organization', '1471-7727', '515',
#         '2.083', '0.000800', '图书情报科学'],
#        ['24', 'Journal of Knowledge Management', '1367-3270', '2,774',
#         '2.053', '0.001470', '图书情报科学'],
#        ['25', 'QUALITATIVE HEALTH RESEARCH', '1049-7323', '6,733',
#         '2.036', '0.007160', '图书情报科学'],
#        ['26', 'MIS Quarterly Executive', '1540-1960', '483', '1.741',
#         '0.000670', '图书情报科学'],
#        ['27', 'Information Development', '0266-6669', '319', '1.691',
#         '0.000450', '图书情报科学'],
#        ['28', 'JOURNAL OF THE MEDICAL LIBRARY ASSOCIATION', '1536-5050',
#         '829', '1.638', '0.000960', '图书情报科学'],
#        ['29', 'JOURNAL OF HEALTH COMMUNICATION', '1081-0730', '3,233',
#         '1.614', '0.007070', '图书情报科学'],
#        ['30', 'INFORMATION SOCIETY', '0197-2243', '1,042', '1.558',
#         '0.000750', '图书情报科学'],
#        ['31', 'ONLINE INFORMATION REVIEW', '1468-4527', '1,042', '1.534',
#         '0.001160', '图书情报科学'],
#        ['32', 'TELECOMMUNICATIONS POLICY', '0308-5961', '1,509', '1.526',
#         '0.002270', '图书情报科学'],
#        ['33', 'COLLEGE & RESEARCH LIBRARIES', '0010-0870', '977',
#         '1.515', '0.001240', '图书情报科学'],
#        ['34', 'Aslib Journal of Information Management', '2050-3806',
#         '118', '1.514', '0.000340', '图书情报科学'],
#        ['35', 'Ethics and Information Technology', '1388-1957', '569',
#         '1.500', '0.000530', '图书情报科学'],
#        ['36', 'JOURNAL OF INFORMATION SCIENCE', '0165-5515', '1,585',
#         '1.372', '0.001560', '图书情报科学'],
#        ['37', 'Information Technology & People', '0959-3845', '642',
#         '1.339', '0.000510', '图书情报科学'],
#        ['38', 'Information Technology for Development', '0268-1102',
#         '382', '1.333', '0.000480', '图书情报科学'],
#        ['38', 'LEARNED PUBLISHING', '0953-1513', '322', '1.333',
#         '0.000700', '图书情报科学'],
#        ['40', 'PORTAL-LIBRARIES AND THE ACADEMY', '1531-2542', '445',
#         '1.290', '0.000880', '图书情报科学'],
#        ['41', 'JOURNAL OF ACADEMIC LIBRARIANSHIP', '0099-1333', '1,241',
#         '1.287', '0.001360', '图书情报科学'],
#        ['42', 'LIBRARY & INFORMATION SCIENCE RESEARCH', '0740-8188',
#         '962', '1.185', '0.001160', '图书情报科学'],
#        ['43', 'Journal of Global Information Technology Management',
#         '1097-198X', '228', '1.167', '0.000160', '图书情报科学'],
#        ['44', 'Information Technology & Management', '1385-951X', '281',
#         '1.067', '0.000420', '图书情报科学'],
#        ['45', 'Profesional de la Informacion', '1386-6710', '466',
#         '1.063', '0.000450', '图书情报科学'],
#        ['46', 'INFORMATION TECHNOLOGY AND LIBRARIES', '0730-9295', '260',
#         '1.029', '0.000390', '图书情报科学'],
#        ['47', 'JOURNAL OF LIBRARIANSHIP AND INFORMATION SCIENCE',
#         '0961-0006', '352', '1.019', '0.000580', '图书情报科学'],
#        ['48', 'Knowledge Management Research & Practice', '1477-8238',
#         '540', '1.013', '0.000480', '图书情报科学'],
#        ['49', 'Health Information and Libraries Journal', '1471-1834',
#         '663', '0.875', '0.000710', '图书情报科学'],
#        ['50', 'JOURNAL OF DOCUMENTATION', '0022-0418', '1,497', '0.853',
#         '0.001040', '图书情报科学'],
#        ['51', 'KNOWLEDGE ORGANIZATION', '0943-7444', '297', '0.831',
#         '0.000140', '图书情报科学'],
#        ['52', 'Journal of Organizational and End User Computing',
#         '1546-2234', '138', '0.759', '0.000050', '图书情报科学'],
#        ['52', 'LIBRARY HI TECH', '0737-8831', '454', '0.759', '0.000720',
#         '图书情报科学'],
#        ['54', 'Revista Espanola de Documentacion Cientifica',
#         '0210-0614', '248', '0.746', '0.000260', '图书情报科学'],
#        ['55', 'Malaysian Journal of Library & Information Science',
#         '1394-6234', '134', '0.650', '0.000240', '图书情报科学'],
#        ['56', 'Australian Academic & Research Libraries', '0004-8623',
#         '177', '0.647', '0.000300', '图书情报科学'],
#        ['57', 'INFORMATION RESEARCH-AN INTERNATIONAL ELECTRONIC JOURNAL',
#         '1368-1613', '732', '0.574', '0.000900', '图书情报科学'],
#        ['58', 'LIBRARY QUARTERLY', '0024-2519', '474', '0.558',
#         '0.000480', '图书情报科学'],
#        ['59', 'PROGRAM-ELECTRONIC LIBRARY AND INFORMATION SYSTEMS',
#         '0033-0337', '330', '0.556', '0.000370', '图书情报科学'],
#        ['60', 'LAW LIBRARY JOURNAL', '0023-9283', '283', '0.540',
#         '0.000110', '图书情报科学'],
#        ['61', 'Journal of Global Information Management', '1062-7375',
#         '319', '0.517', '0.000130', '图书情报科学'],
#        ['62', 'SOCIAL SCIENCE INFORMATION SUR LES SCIENCES SOCIALES',
#         '0539-0184', '862', '0.490', '0.000570', '图书情报科学'],
#        ['63', 'ELECTRONIC LIBRARY', '0264-0473', '382', '0.484',
#         '0.000430', '图书情报科学'],
#        ['63', 'LIBRARY RESOURCES & TECHNICAL SERVICES', '0024-2527',
#         '165', '0.484', '0.000160', '图书情报科学'],
#        ['65', 'JOURNAL OF SCHOLARLY PUBLISHING', '1198-9742', '100',
#         '0.472', '0.000120', '图书情报科学'],
#        ['66', 'DATA BASE FOR ADVANCES IN INFORMATION SYSTEMS',
#         '0095-0033', '585', '0.458', '0.000240', '图书情报科学'],
#        ['67', 'LIBRI', '0024-2667', '213', '0.400', '0.000280', '图书情报科学'],
#        ['68', 'SERIALS REVIEW', '0098-7913', '184', '0.379', '0.000350',
#         '图书情报科学'],
#        ['69',
#         'RESTAURATOR-INTERNATIONAL JOURNAL FOR THE PRESERVATION OF LIBRARY AND ARCHIVAL MATERIAL',
#         '0034-5806', '196', '0.367', '0.000090', '图书情报科学'],
#        ['70', 'Information & Culture', '2164-8034', '59', '0.364',
#         '0.000180', '图书情报科学'],
#        ['70', 'LIBRARY AND INFORMATION SCIENCE', '0373-4447', '29',
#         '0.364', '0.000030', '图书情报科学'],
#        ['72', 'Transinformacao', '0103-3786', '60', '0.352', '0.000080',
#         '图书情报科学'],
#        ['73', 'REFERENCE & USER SERVICES QUARTERLY', '1094-9054', '261',
#         '0.339', '0.000240', '图书情报科学'],
#        ['74', 'SCIENTIST', '0890-3670', '236', '0.325', '0.000300',
#         '图书情报科学'],
#        ['75', 'LIBRARY TRENDS', '0024-2594', '663', '0.259', '0.000650',
#         '图书情报科学'],
#        ['76', 'Australian Library Journal', '0004-9670', '103', '0.255',
#         '0.000190', '图书情报科学'],
#        ['77', 'LIBRARY COLLECTIONS ACQUISITIONS & TECHNICAL SERVICES',
#         '1464-9055', '149', '0.200', '0.000110', '图书情报科学'],
#        ['78',
#         'African Journal of Library Archives and Information Science',
#         '0795-4778', '48', '0.179', '0.000020', '图书情报科学'],
#        ['79', 'INTERLENDING & DOCUMENT SUPPLY', '0264-1615', '80',
#         '0.175', '0.000030', '图书情报科学'],
#        ['80', 'ZEITSCHRIFT FUR BIBLIOTHEKSWESEN UND BIBLIOGRAPHIE',
#         '0044-2380', '31', '0.158', '0.000010', '图书情报科学'],
#        ['81', 'Investigacion Bibliotecologica', '0187-358X', '65',
#         '0.125', '0.000040', '图书情报科学'],
#        ['82',
#         'CANADIAN JOURNAL OF INFORMATION AND LIBRARY SCIENCE-REVUE CANADIENNE DES SCIENCES DE L INFORMATION ET DE BIBLIOTHECONOMIE',
#         '1195-096X', '57', '0.111', '0.000030', '图书情报科学'],
#        ['83', 'Informacao & Sociedade-Estudos', '0104-0146', '54',
#         '0.086', '0.000040', '图书情报科学'],
#        ['84', 'ECONTENT', '1525-2531', '17', '0.025', '0.000020',
#         '图书情报科学'],
#        ['85', 'Informacios Tarsadalom', '1587-8694', '4', '0.022',
#         '0.000000', '图书情报科学']], dtype='<U121')
