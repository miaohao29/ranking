# %%
import csv,os
import pandas as pd
import numpy as np
import re

# %%
Folder_Path =r'C:\Users\rk\Downloads\GRAS'        #要拼接的文件夹及其完整路径，注意不要包含中文
SaveFile_Path =  r'C:\Users\rk\Downloads\GRASresult'       #拼接后要保存的文件路径
SaveFile_Name = r'GRAS.csv'              #合并后要保存的文件名
    
os.chdir(Folder_Path)#修改当前工作目录
file_list = os.listdir() #将该文件夹下的所有文件名存入一个列表

# %%
file_list
# Out:
# ['Agricultural Economics.csv',
#  'Agricultural Engineering.csv',
#  'Agricultural Sciences.csv',
#  'Atmospheric Science.csv',
#  'Automation & Control.csv',
#  'Biological Sciences.csv',
#  'Biomedical Engineering.csv',
#  'Biotechnology.csv',
#  'Business Administration.csv',
#  'Chemical Engineering.csv',
#  'Chemistry.csv',
#  'Civil Engineering.csv',
#  'Clinical Medicine.csv',
#  'Communication.csv',
#  'Computer Science & Engineering.csv',
#  'Dentistry & Oral Sciences.csv',
#  'Earth Sciences.csv',
#  'Ecology.csv',
#  'Economics.csv',
#  'Education.csv',
#  'Electrical & Electronic Engineering.csv',
#  'Energy Science & Engineering.csv',
#  'Environmental Science & Engineering.csv',
#  'Finance.csv',
#  'Food Science & Technology.csv',
#  'Geography.csv',
#  'Geological Engineering.csv',
#  'Hospitality & Tourism Management.csv',
#  'Human Biological Sciences.csv',
#  'Instruments Science & Technology.csv',
#  'Law.csv',
#  'Library & Information Science.csv',
#  'Management.csv',
#  'Marine_Ocean Engineering.csv',
#  'Materials Science & Engineering.csv',
#  'Mathematics.csv',
#  'Mechanical Engineering.csv',
#  'Medical Technology.csv',
#  'Metallurgical Engineering.csv',
#  'Mining & Mineral Engineering.csv',
#  'Nanoscience & Nanotechnology.csv',
#  'Nursing.csv',
#  'Oceanography.csv',
#  'Pharmacy & Pharmaceutical Sciences.csv',
#  'Physics.csv',
#  'Political Sciences.csv',
#  'Psychology.csv',
#  'Public Administration.csv',
#  'Public Health.csv',
#  'Remote Sensing.csv',
#  'Sociology.csv',
#  'Statistics.csv',
#  'Telecommunication Engineering.csv',
#  'Transportation Science & Technology.csv',
#  'Veterinary Sciences.csv',
#  'Water Resources.csv',
#  '数学']

# %%
#读入csv中的数据，（导入检索式）
a = []
csv_reader=csv.reader(open(Folder_Path +'\\'+ file_list[1],encoding='utf-8'))#打开第一个文件
for row in csv_reader:
    a.append(row)#将读入的数据赋值给列表a

# %%
a[0].append("学科")#第一行的最后增加“学科”列
Subject=re.sub('\.csv','',file_list[0])#根据文件名，提取学科名称
for element in a[1:]:
    element.append(Subject)#将学科类添加到每行的最后“学科”列
del a[-11:]#删除第一个文件后11行多余的数据

# %%
for i in range(1,len(file_list)):#依次从第二个文件开始循环
    e=[]
    csv_reader=csv.reader(open(Folder_Path +'\\'+ file_list[i],encoding='utf-8'))
    Sub=re.sub('\.csv','',file_list[i])
    for row in csv_reader:
        e.append(row)#将读入的数据赋值给列表
    for item in e[1:-11]:
        item.append(Sub)#除第1行及最后11行外，每行的最后添加学科名称
        a.append(item)#将添加学科后的每行数据拼接到列表a 中

# %%
a[0]
# Out:
# ['名称', '排名', 'Web of Science 论文数', '学科规范化的引文影响力', '国际合作论文百分比', '学科']

# %%
len(a)
# Out:
# 179441

# %%
univer1=['China University of Geosciences',
        'China University of Mining and Technology',
        'China University of Petroleum']

# %%
b=[]
for item in a:
    if item[0] not in univer1:
        
        b.append(item)
    if item[0] in univer1:
        print(item)
# Out:
# ['China University of Geosciences', '232', '25', '1.3752320000000002', '56.00000000000001', 'Agricultural Economics']
# ['China University of Petroleum', '234', '27', '1.6722629629629626', '62.96296296296296', 'Agricultural Economics']
# ['China University of Geosciences', '232', '25', '1.3752320000000002', '56.00000000000001', 'Agricultural Engineering']
# ['China University of Petroleum', '234', '27', '1.6722629629629626', '62.96296296296296', 'Agricultural Engineering']
# ['China University of Geosciences', '488', '68', '0.9669779411764705', '41.17647058823529', 'Agricultural Sciences']
# ['China University of Petroleum', '490', '10', '0.7923199999999999', '20.0', 'Agricultural Sciences']
# ['China University of Geosciences', '333', '160', '0.557438125', '25.0', 'Atmospheric Science']
# ['China University of Petroleum', '335', '21', '0.5885476190476191', '33.33333333333333', 'Atmospheric Science']
# ['China University of Geosciences', '311', '56', '2.8321232142857147', '51.78571428571429', 'Automation & Control']
# ['China University of Petroleum', '313', '106', '2.2197179245283025', '29.245283018867923', 'Automation & Control']
# ['China University of Geosciences', '608', '256', '1.003449609375', '42.96875', 'Biological Sciences']
# ['China University of Petroleum', '610', '171', '0.9004959064327488', '33.33333333333333', 'Biological Sciences']
# ['China University of Geosciences', '358', '14', '0.6821142857142857', '7.142857142857142', 'Biomedical Engineering']
# ['China University of Petroleum', '360', '18', '0.6663111111111112', '38.88888888888889', 'Biomedical Engineering']
# ['China University of Geosciences', '468', '75', '0.9903360000000003', '38.666666666666664', 'Biotechnology']
# ['China University of Petroleum', '470', '70', '1.0107342857142856', '40.0', 'Biotechnology']
# ['China University of Geosciences', '313', '4', '1.6285250000000002', '100.0', 'Business Administration']
# ['China University of Petroleum', '315', '5', '1.3978800000000002', '80.0', 'Business Administration']
# ['China University of Geosciences', '436', '423', '1.2230886524822697', '25.53191489361702', 'Chemical Engineering']
# ['China University of Petroleum', '438', '1813', '0.8142586321014894', '20.573634859349145', 'Chemical Engineering']
# ['China University of Geosciences', '597', '1272', '1.197505896226415', '25.157232704402517', 'Chemistry']
# ['China University of Petroleum', '599', '1957', '1.0666923352069497', '17.935615738375063', 'Chemistry']
# ['China University of Geosciences', '332', '125', '1.1101496', '39.2', 'Civil Engineering']
# ['China University of Petroleum', '334', '84', '1.1356940476190478', '30.952380952380953', 'Civil Engineering']
# ['China University of Geosciences', '538', '16', '1.0359187500000002', '18.75', 'Clinical Medicine']
# ['China University of Petroleum', '540', '7', '0.4121714285714286', '42.857142857142854', 'Clinical Medicine']
# ['China University of Geosciences', '510', '364', '1.6676343406593408', '51.098901098901095', 'Computer Science & Engineering']
# ['China University of Petroleum', '512', '282', '1.3117219858156024', '39.00709219858156', 'Computer Science & Engineering']
# ['China University of Geosciences', '419', '4529', '1.3099171561051006', '42.702583351733274', 'Earth Sciences']
# ['China University of Petroleum', '421', '1287', '0.9293066822066824', '29.059829059829063', 'Earth Sciences']
# ['China University of Geosciences', '395', '69', '0.9839000000000002', '43.47826086956522', 'Ecology']
# ['China University of Petroleum', '397', '4', '0.80335', '25.0', 'Ecology']
# ['China University of Geosciences', '112', '1', '0.0', '0.0', 'Economics']
# ['China University of Petroleum', '113', '2', '0.0', '0.0', 'Economics']
# ['China University of Geosciences', '403', '5', '1.50476', '40.0', 'Education']
# ['China University of Geosciences', '461', '282', '1.4025241134751771', '35.815602836879435', 'Electrical & Electronic Engineering']
# ['China University of Petroleum', '463', '225', '1.4102991111111116', '37.333333333333336', 'Electrical & Electronic Engineering']
# ['China University of Geosciences', '462', '649', '1.2964767334360554', '30.662557781201848', 'Energy Science & Engineering']
# ['China University of Petroleum', '464', '2066', '0.9485581316553732', '21.055179090029043', 'Energy Science & Engineering']
# ['China University of Geosciences', '548', '937', '1.0040588046958379', '36.49946638207044', 'Environmental Science & Engineering']
# ['China University of Petroleum', '550', '348', '1.169043965517241', '25.287356321839084', 'Environmental Science & Engineering']
# ['China University of Geosciences', '209', '1', '0.5284', '100.0', 'Finance']
# ['China University of Petroleum', '211', '1', '5.421200000000001', '0.0', 'Finance']
# ['China University of Geosciences', '413', '28', '0.518575', '10.714285714285714', 'Food Science & Technology']
# ['China University of Petroleum', '415', '19', '0.8070473684210527', '10.526315789473683', 'Food Science & Technology']
# ['China University of Geosciences', '323', '242', '1.1868504132231408', '51.2396694214876', 'Geography']
# ['China University of Petroleum', '325', '13', '0.8999923076923076', '46.15384615384615', 'Geography']
# ['China University of Geosciences', '167', '112', '1.2517705357142854', '45.535714285714285', 'Geological Engineering']
# ['China University of Petroleum', '169', '39', '1.1731641025641026', '56.41025641025641', 'Geological Engineering']
# ['China University of Geosciences', '182', '1', '2.7083', '100.0', 'Hospitality & Tourism Management']
# ['China University of Geosciences', '525', '14', '1.2561357142857148', '57.14285714285714', 'Human Biological Sciences']
# ['China University of Petroleum', '527', '14', '0.3723571428571429', '42.857142857142854', 'Human Biological Sciences']
# ['China University of Geosciences', '388', '61', '0.8665950819672135', '34.42622950819672', 'Instruments Science & Technology']
# ['China University of Petroleum', '390', '108', '1.204247222222222', '24.074074074074073', 'Instruments Science & Technology']
# ['China University of Geosciences', '267', '8', '0.7494875000000001', '37.5', 'Library & Information Science']
# ['China University of Petroleum', '269', '2', '0.6871', '50.0', 'Library & Information Science']
# ['China University of Geosciences', '400', '26', '1.918973076923077', '53.84615384615385', 'Management']
# ['China University of Petroleum', '402', '41', '1.5684853658536586', '29.268292682926827', 'Management']
# ['China University of Geosciences', '113', '7', '0.32654285714285713', '14.285714285714285', 'Marine_Ocean Engineering']
# ['China University of Petroleum', '115', '67', '0.7537522388059703', '23.88059701492537', 'Marine_Ocean Engineering']
# ['China University of Geosciences', '541', '1080', '1.0874221296296298', '22.87037037037037', 'Materials Science & Engineering']
# ['China University of Petroleum', '543', '1068', '1.2120385767790265', '25.0', 'Materials Science & Engineering']
# ['China University of Geosciences', '451', '113', '1.1876840707964602', '28.31858407079646', 'Mathematics']
# ['China University of Petroleum', '453', '275', '1.0919334545454547', '17.09090909090909', 'Mathematics']
# ['China University of Geosciences', '397', '97', '1.092805154639175', '16.49484536082474', 'Mechanical Engineering']
# ['China University of Petroleum', '399', '339', '0.8791554572271385', '16.519174041297934', 'Mechanical Engineering']
# ['China University of Geosciences', '354', '6', '0.6656833333333333', '50.0', 'Medical Technology']
# ['China University of Petroleum', '356', '6', '0.38491666666666663', '33.33333333333333', 'Medical Technology']
# ['China University of Geosciences', '340', '167', '0.6699694610778443', '13.17365269461078', 'Metallurgical Engineering']
# ['China University of Petroleum', '342', '163', '0.9131214723926382', '14.11042944785276', 'Metallurgical Engineering']
# ['China University of Geosciences', '148', '223', '1.5758385650224211', '34.97757847533632', 'Mining & Mineral Engineering']
# ['China University of Petroleum', '150', '65', '1.1635430769230772', '46.15384615384615', 'Mining & Mineral Engineering']
# ['China University of Geosciences', '422', '191', '1.481144502617801', '35.07853403141361', 'Nanoscience & Nanotechnology']
# ['China University of Petroleum', '424', '272', '1.328297794117647', '34.19117647058824', 'Nanoscience & Nanotechnology']
# ['China University of Geosciences', '235', '76', '0.7022447368421052', '47.368421052631575', 'Oceanography']
# ['China University of Petroleum', '237', '61', '0.791934426229508', '19.672131147540984', 'Oceanography']
# ['China University of Geosciences', '492', '51', '0.623743137254902', '17.647058823529413', 'Pharmacy & Pharmaceutical Sciences']
# ['China University of Petroleum', '494', '9', '1.8549111111111114', '33.33333333333333', 'Pharmacy & Pharmaceutical Sciences']
# ['China University of Geosciences', '575', '770', '0.8869698701298702', '19.350649350649352', 'Physics']
# ['China University of Petroleum', '577', '785', '0.8463588535031847', '24.713375796178344', 'Physics']
# ['China University of Geosciences', '254', '1', '0.6616000000000001', '0.0', 'Political Sciences']
# ['China University of Petroleum', '256', '3', '1.2404666666666666', '66.66666666666666', 'Political Sciences']
# ['China University of Geosciences', '437', '4', '0.382925', '75.0', 'Psychology']
# ['China University of Petroleum', '439', '1', '11.4663', '100.0', 'Psychology']
# ['China University of Geosciences', '530', '27', '0.8548185185185185', '40.74074074074074', 'Public Health']
# ['China University of Petroleum', '532', '10', '0.8252', '20.0', 'Public Health']
# ['China University of Geosciences', '220', '138', '0.9343963768115944', '34.78260869565217', 'Remote Sensing']
# ['China University of Petroleum', '222', '30', '1.5425100000000005', '43.333333333333336', 'Remote Sensing']
# ['China University of Geosciences', '266', '1', '1.901', '0.0', 'Sociology']
# ['China University of Geosciences', '318', '22', '0.4268818181818182', '36.36363636363637', 'Statistics']
# ['China University of Petroleum', '320', '11', '1.2754', '54.54545454545454', 'Statistics']
# ['China University of Geosciences', '320', '83', '0.8858277108433734', '60.24096385542169', 'Telecommunication Engineering']
# ['China University of Petroleum', '322', '60', '0.73697', '33.33333333333333', 'Telecommunication Engineering']
# ['China University of Geosciences', '236', '10', '1.32301', '40.0', 'Transportation Science & Technology']
# ['China University of Petroleum', '238', '4', '0.9155500000000001', '0.0', 'Transportation Science & Technology']
# ['China University of Geosciences', '387', '496', '0.7968550403225806', '37.29838709677419', 'Water Resources']
# ['China University of Petroleum', '389', '61', '0.45317049180327873', '18.0327868852459', 'Water Resources']
# ['China University of Geosciences', '150', '2', '0.19455', '50.0', '数学']
# ['China University of Petroleum', '152', '1', '0.0', '0.0', '数学']

# %%
len(b)
# Out:
# 179342

# %%
len(a)-len(b)
# Out:
# 99

# %%
univer2=['China University of Geosciences - Beijing',
        'China University of Geosciences (Wuhan)',
        'China University of Mining and Technology, Beijing',
        'China University of Mining and Technology',
        'China University of Petroleum - Beijing',
        'China University of Petroleum - Eastern China']

# %%
lis_a=[]
csv_reader=csv.reader(open(r'C:\Users\rk\Desktop\Mapp.csv'))
for line in csv_reader:
    lis_a.append(line)

# %%
lis_a
# Out:
# [['Mathematics', 'Mathematics'],
#  ['Mathematics', 'Mathematics, Applied'],
#  ['Physics', 'Acoustics'],
#  ['Physics', 'Astronomy & Astrophysics'],
#  ['Physics', 'Optics'],
#  ['Physics', 'Physics, Applied'],
#  ['Physics', 'Physics, Atomic, Molecular & Chemical'],
#  ['Physics', 'Physics, Condensed Matter'],
#  ['Physics', 'Physics, Fluids & Plasmas'],
#  ['Physics', 'Physics, Mathematical'],
#  ['Physics', 'Physics, Multidisciplinary'],
#  ['Physics', 'Physics, Nuclear'],
#  ['Physics', 'Physics, Particles & Fields'],
#  ['Chemistry', 'Chemistry, Analytical'],
#  ['Chemistry', 'Chemistry, Applied'],
#  ['Chemistry', 'Chemistry, Inorganic & Nuclear'],
#  ['Chemistry', 'Chemistry, Multidisciplinary'],
#  ['Chemistry', 'Chemistry, Organic'],
#  ['Chemistry', 'Chemistry, Physical'],
#  ['Chemistry', 'Crystallography'],
#  ['Chemistry', 'Electrochemistry'],
#  ['Chemistry', 'Spectroscopy'],
#  ['Chemistry', 'Polymer Science'],
#  ['Earth Sciences', 'Geochemistry & Geophysics'],
#  ['Earth Sciences', 'Geology'],
#  ['Earth Sciences', 'Geosciences, Multidisciplinary'],
#  ['Earth Sciences', 'Mineralogy'],
#  ['Earth Sciences', 'Paleontology'],
#  ['Geography', 'Area Studies'],
#  ['Geography', 'Geography'],
#  ['Geography', 'Geography, Physical'],
#  ['Ecology', 'Biodiversity Conservation'],
#  ['Ecology', 'Ecology'],
#  ['Oceanography', 'Oceanography'],
#  ['Atmospheric Science', 'Meteorology & Atmospheric Sciences'],
#  ['Mechanical Engineering', 'Engineering, Manufacturing'],
#  ['Mechanical Engineering', 'Engineering, Mechanical'],
#  ['Electrical & Electronic Engineering',
#   'Engineering, Electrical & Electronic'],
#  ['Electrical & Electronic Engineering',
#   'Imaging Science & Photographic Technology'],
#  ['Automation & Control', 'Automation & Control Systems'],
#  ['Automation & Control', 'Robotics'],
#  ['Telecommunication Engineering', 'Telecommunications'],
#  ['Instruments Science & Technology', 'Instruments & Instrumentation'],
#  ['Instruments Science & Technology', 'Microscopy'],
#  ['Biomedical Engineering', 'Cell & Tissue Engineering'],
#  ['Biomedical Engineering', 'Engineering, Biomedical'],
#  ['Computer Science & Engineering', 'Computer Science, Information Systems'],
#  ['Computer Science & Engineering', 'Computer Science, Cybernetics'],
#  ['Computer Science & Engineering', 'Computer Science, Software Engineering'],
#  ['Computer Science & Engineering',
#   'Computer Science, Artificial Intelligence'],
#  ['Computer Science & Engineering',
#   'Computer Science, Hardware & Architecture'],
#  ['Computer Science & Engineering', 'Computer Science, Theory & Methods'],
#  ['Computer Science & Engineering',
#   'Computer Science, Interdisciplinary Applications'],
#  ['Civil Engineering', 'Construction & Building Technology'],
#  ['Civil Engineering', 'Engineering, Civil'],
#  ['Chemical Engineering', 'Engineering, Chemical'],
#  ['Materials Science & Engineering', 'Materials Science, Biomaterials'],
#  ['Materials Science & Engineering', 'Materials Science, Ceramics'],
#  ['Materials Science & Engineering',
#   'Materials Science, Characterization & Testing'],
#  ['Materials Science & Engineering', 'Materials Science, Coatings & Films'],
#  ['Materials Science & Engineering', 'Materials Science, Composites'],
#  ['Materials Science & Engineering', 'Materials Science, Multidisciplinary'],
#  ['Materials Science & Engineering', 'Materials Science, Paper & Wood'],
#  ['Materials Science & Engineering', 'Materials Science, Textiles'],
#  ['Nanoscience & Nanotechnology', 'Nanoscience & Nanotechnology'],
#  ['Energy Science & Engineering', 'Energy & Fuels'],
#  ['Energy Science & Engineering', 'Nuclear Science & Technology'],
#  ['Energy Science & Engineering', 'Engineering, Petroleum'],
#  ['Environmental Science & Engineering', 'Engineering, Environmental'],
#  ['Environmental Science & Engineering', 'Environmental Sciences'],
#  ['Environmental Science & Engineering', 'Environmental Studies'],
#  ['Water Resources', 'Water Resources'],
#  ['Agricultural Engineering', 'Agricultural Engineering'],
#  ['Food Science & Technology', 'Food Science & Technology'],
#  ['Biotechnology', 'Biotechnology & Applied Microbiology'],
#  ['Aerospace Engineering', 'Engineering, Aerospace'],
#  ['Marine/Ocean Engineering', 'Engineering, Marine'],
#  ['Marine/Ocean Engineering', 'Engineering, Ocean'],
#  ['Transportation Science & Technology', 'Transportation'],
#  ['Transportation Science & Technology',
#   'Transportation Science & Technology'],
#  ['Remote Sensing', 'Remote Sensing'],
#  ['Geological Engineering', 'Engineering, Geological'],
#  ['Mining & Mineral Engineering', 'Mining & Mineral Processing'],
#  ['Metallurgical Engineering', 'Metallurgy & Metallurgical Engineering'],
#  ['Biological Sciences', 'Biochemical Research Methods'],
#  ['Biological Sciences', 'Biochemistry & Molecular Biology'],
#  ['Biological Sciences', 'Biology'],
#  ['Biological Sciences', 'Biophysics'],
#  ['Biological Sciences', 'Cell Biology'],
#  ['Biological Sciences', 'Developmental Biology'],
#  ['Biological Sciences', 'Entomology'],
#  ['Biological Sciences', 'Evolutionary Biology'],
#  ['Biological Sciences', 'Genetics & Heredity'],
#  ['Biological Sciences', 'Limnology'],
#  ['Biological Sciences', 'Marine & Freshwater Biology'],
#  ['Biological Sciences', 'Mathematical & Computational Biology'],
#  ['Biological Sciences', 'Microbiology'],
#  ['Biological Sciences', 'Mycology'],
#  ['Biological Sciences', 'Ornithology'],
#  ['Biological Sciences', 'Physiology'],
#  ['Biological Sciences', 'Reproductive Biology'],
#  ['Biological Sciences', 'Virology'],
#  ['Biological Sciences', 'Zoology'],
#  ['Human Biological Sciences', 'Neurosciences'],
#  ['Human Biological Sciences', 'Anatomy & Morphology'],
#  ['Human Biological Sciences', 'Parasitology'],
#  ['Human Biological Sciences', 'Pathology'],
#  ['Human Biological Sciences', 'Immunology'],
#  ['Human Biological Sciences', 'Medical Informatics'],
#  ['Human Biological Sciences', 'Medicine, Research & Experimental'],
#  ['Agricultural Sciences', 'Agronomy'],
#  ['Agricultural Sciences', 'Horticulture'],
#  ['Agricultural Sciences', 'Fisheries'],
#  ['Agricultural Sciences', 'Soil Science'],
#  ['Agricultural Sciences', 'Forestry'],
#  ['Agricultural Sciences', 'Agriculture, Dairy & Animal Science'],
#  ['Agricultural Sciences', 'Agriculture, Multidisciplinary'],
#  ['Agricultural Sciences', 'Plant Sciences'],
#  ['Veterinary Sciences', 'Veterinary Sciences'],
#  ['Clinical Medicine', 'Allergy'],
#  ['Clinical Medicine', 'Andrology'],
#  ['Clinical Medicine', 'Anesthesiology'],
#  ['Clinical Medicine', 'Cardiac & Cardiovascular Systems'],
#  ['Clinical Medicine', 'Clinical Neurology'],
#  ['Clinical Medicine', 'Critical Care Medicine'],
#  ['Clinical Medicine', 'Dermatology'],
#  ['Clinical Medicine', 'Emergency Medicine'],
#  ['Clinical Medicine', 'Endocrinology & Metabolism'],
#  ['Clinical Medicine', 'Gastroenterology & Hepatology'],
#  ['Clinical Medicine', 'Geriatrics & Gerontology'],
#  ['Clinical Medicine', 'Gerontology'],
#  ['Clinical Medicine', 'Hematology'],
#  ['Clinical Medicine', 'Integrative & Complementary Medicine'],
#  ['Clinical Medicine', 'Medicine, General & Internal'],
#  ['Clinical Medicine', 'Obstetrics & Gynecology'],
#  ['Clinical Medicine', 'Oncology'],
#  ['Clinical Medicine', 'Ophthalmology'],
#  ['Clinical Medicine', 'Orthopedics'],
#  ['Clinical Medicine', 'Otorhinolaryngology'],
#  ['Clinical Medicine', 'Pediatrics'],
#  ['Clinical Medicine', 'Peripheral Vascular Disease'],
#  ['Clinical Medicine', 'Psychiatry'],
#  ['Clinical Medicine', 'Rehabilitation'],
#  ['Clinical Medicine', 'Respiratory System'],
#  ['Clinical Medicine', 'Rheumatology'],
#  ['Clinical Medicine', 'Surgery'],
#  ['Clinical Medicine', 'Transplantation'],
#  ['Clinical Medicine', 'Tropical Medicine'],
#  ['Clinical Medicine', 'Urology & Nephrology'],
#  ['Clinical Medicine', 'Audiology & Speech-Language Pathology'],
#  ['Public Health', 'Health Policy & Services'],
#  ['Public Health', 'Health Care Sciences & Services'],
#  ['Public Health', 'Infectious Diseases'],
#  ['Public Health', 'Nutrition & Dietetics'],
#  ['Public Health', 'Primary Health Care'],
#  ['Public Health', 'Public, Environmental & Occupational Health'],
#  ['Public Health', 'Social Sciences, Biomedical'],
#  ['Public Health', 'Substance Abuse'],
#  ['Public Health', 'Ergonomics'],
#  ['Dentistry & Oral Sciences', 'Dentistry, Oral Surgery & Medicine'],
#  ['Nursing', 'Nursing'],
#  ['Medical Technology', 'Medical Laboratory Technology'],
#  ['Medical Technology', 'Neuroimaging'],
#  ['Medical Technology', 'Radiology, Nuclear Medicine & Medical Imaging'],
#  ['Pharmacy & Pharmaceutical Sciences', 'Chemistry, Medicinal'],
#  ['Pharmacy & Pharmaceutical Sciences', 'Pharmacology & Pharmacy'],
#  ['Pharmacy & Pharmaceutical Sciences', 'Toxicology'],
#  ['Economics', 'Economics'],
#  ['Statistics', 'Statistics & Probability'],
#  ['Law', 'Criminology & Penology'],
#  ['Law', 'Law'],
#  ['Political Sciences', 'International Relations'],
#  ['Political Sciences', 'Political Science'],
#  ['Sociology', 'Sociology'],
#  ['Education', 'Education & Educational Research'],
#  ['Education', 'Education, Scientific Disciplines'],
#  ['Education', 'Education, Special'],
#  ['Communication', 'Communication'],
#  ['Psychology', 'Psychology'],
#  ['Psychology', 'Psychology, Applied'],
#  ['Psychology', 'Psychology, Biological'],
#  ['Psychology', 'Psychology, Clinical'],
#  ['Psychology', 'Psychology, Developmental'],
#  ['Psychology', 'Psychology, Educational'],
#  ['Psychology', 'Psychology, Experimental'],
#  ['Psychology', 'Psychology, Mathematical'],
#  ['Psychology', 'Psychology, Multidisciplinary'],
#  ['Psychology', 'Psychology, Psychoanalysis'],
#  ['Psychology', 'Psychology, Social'],
#  ['Psychology', 'Behavioral Sciences'],
#  ['Business Administration', 'Business'],
#  ['Business Administration', 'Industrial Relations & Labor'],
#  ['Finance', 'Business, Finance'],
#  ['Management', 'Management'],
#  ['Management', 'Operations Research & Management Science'],
#  ['Public Administration', 'Public Administration'],
#  ['Hospitality & Tourism Management', 'Hospitality, Leisure, Sport & Tourism'],
#  ['Agricultural Economics', 'Agricultural Economics & Policy'],
#  ['Library & Information Science', 'Information Science & Library Science']]

# %%
####################运用此程序的前提是：先在原文件里做好分类汇总####################################
final_lis=[]
counter=0
while True:#为了是for循环中的起始值counter的改变，for进入循环后，起始值不再改变，
    for item_1 in lis_a[counter:]:
        diction=[]
        lis_c=[]
        initial_s=0
        lis_c.append(item_1[1])#将第一个期刊加入列表，在此处加入是防止仅出现一次而忽略
        for item_2 in lis_a[counter+1:]:
            if item_1[0]==item_2[0]:
                lis_c.append(item_2[1])#将相同的期刊加入列表
                initial_s+=1 #每找到一个相同的就把initial_s加一，     
        diction.append(item_1[0])
        diction.append(lis_c)
        final_lis.append(diction)
        break#为了使for循环中的起始值改变，循环一次后利用break强制退出for循环，利用while进入下一次循环
    counter=counter+initial_s+1
    if counter>=len(lis_a):#为了使while循环跳出,当大于列表长度的时候跳出循环
        break

# %%
final_lis
# Out:
# [['Mathematics', ['Mathematics', 'Mathematics, Applied']],
#  ['Physics',
#   ['Acoustics',
#    'Astronomy & Astrophysics',
#    'Optics',
#    'Physics, Applied',
#    'Physics, Atomic, Molecular & Chemical',
#    'Physics, Condensed Matter',
#    'Physics, Fluids & Plasmas',
#    'Physics, Mathematical',
#    'Physics, Multidisciplinary',
#    'Physics, Nuclear',
#    'Physics, Particles & Fields']],
#  ['Chemistry',
#   ['Chemistry, Analytical',
#    'Chemistry, Applied',
#    'Chemistry, Inorganic & Nuclear',
#    'Chemistry, Multidisciplinary',
#    'Chemistry, Organic',
#    'Chemistry, Physical',
#    'Crystallography',
#    'Electrochemistry',
#    'Spectroscopy',
#    'Polymer Science']],
#  ['Earth Sciences',
#   ['Geochemistry & Geophysics',
#    'Geology',
#    'Geosciences, Multidisciplinary',
#    'Mineralogy',
#    'Paleontology']],
#  ['Geography', ['Area Studies', 'Geography', 'Geography, Physical']],
#  ['Ecology', ['Biodiversity Conservation', 'Ecology']],
#  ['Oceanography', ['Oceanography']],
#  ['Atmospheric Science', ['Meteorology & Atmospheric Sciences']],
#  ['Mechanical Engineering',
#   ['Engineering, Manufacturing', 'Engineering, Mechanical']],
#  ['Electrical & Electronic Engineering',
#   ['Engineering, Electrical & Electronic',
#    'Imaging Science & Photographic Technology']],
#  ['Automation & Control', ['Automation & Control Systems', 'Robotics']],
#  ['Telecommunication Engineering', ['Telecommunications']],
#  ['Instruments Science & Technology',
#   ['Instruments & Instrumentation', 'Microscopy']],
#  ['Biomedical Engineering',
#   ['Cell & Tissue Engineering', 'Engineering, Biomedical']],
#  ['Computer Science & Engineering',
#   ['Computer Science, Information Systems',
#    'Computer Science, Cybernetics',
#    'Computer Science, Software Engineering',
#    'Computer Science, Artificial Intelligence',
#    'Computer Science, Hardware & Architecture',
#    'Computer Science, Theory & Methods',
#    'Computer Science, Interdisciplinary Applications']],
#  ['Civil Engineering',
#   ['Construction & Building Technology', 'Engineering, Civil']],
#  ['Chemical Engineering', ['Engineering, Chemical']],
#  ['Materials Science & Engineering',
#   ['Materials Science, Biomaterials',
#    'Materials Science, Ceramics',
#    'Materials Science, Characterization & Testing',
#    'Materials Science, Coatings & Films',
#    'Materials Science, Composites',
#    'Materials Science, Multidisciplinary',
#    'Materials Science, Paper & Wood',
#    'Materials Science, Textiles']],
#  ['Nanoscience & Nanotechnology', ['Nanoscience & Nanotechnology']],
#  ['Energy Science & Engineering',
#   ['Energy & Fuels',
#    'Nuclear Science & Technology',
#    'Engineering, Petroleum']],
#  ['Environmental Science & Engineering',
#   ['Engineering, Environmental',
#    'Environmental Sciences',
#    'Environmental Studies']],
#  ['Water Resources', ['Water Resources']],
#  ['Agricultural Engineering', ['Agricultural Engineering']],
#  ['Food Science & Technology', ['Food Science & Technology']],
#  ['Biotechnology', ['Biotechnology & Applied Microbiology']],
#  ['Aerospace Engineering', ['Engineering, Aerospace']],
#  ['Marine/Ocean Engineering', ['Engineering, Marine', 'Engineering, Ocean']],
#  ['Transportation Science & Technology',
#   ['Transportation', 'Transportation Science & Technology']],
#  ['Remote Sensing', ['Remote Sensing']],
#  ['Geological Engineering', ['Engineering, Geological']],
#  ['Mining & Mineral Engineering', ['Mining & Mineral Processing']],
#  ['Metallurgical Engineering', ['Metallurgy & Metallurgical Engineering']],
#  ['Biological Sciences',
#   ['Biochemical Research Methods',
#    'Biochemistry & Molecular Biology',
#    'Biology',
#    'Biophysics',
#    'Cell Biology',
#    'Developmental Biology',
#    'Entomology',
#    'Evolutionary Biology',
#    'Genetics & Heredity',
#    'Limnology',
#    'Marine & Freshwater Biology',
#    'Mathematical & Computational Biology',
#    'Microbiology',
#    'Mycology',
#    'Ornithology',
#    'Physiology',
#    'Reproductive Biology',
#    'Virology',
#    'Zoology']],
#  ['Human Biological Sciences',
#   ['Neurosciences',
#    'Anatomy & Morphology',
#    'Parasitology',
#    'Pathology',
#    'Immunology',
#    'Medical Informatics',
#    'Medicine, Research & Experimental']],
#  ['Agricultural Sciences',
#   ['Agronomy',
#    'Horticulture',
#    'Fisheries',
#    'Soil Science',
#    'Forestry',
#    'Agriculture, Dairy & Animal Science',
#    'Agriculture, Multidisciplinary',
#    'Plant Sciences']],
#  ['Veterinary Sciences', ['Veterinary Sciences']],
#  ['Clinical Medicine',
#   ['Allergy',
#    'Andrology',
#    'Anesthesiology',
#    'Cardiac & Cardiovascular Systems',
#    'Clinical Neurology',
#    'Critical Care Medicine',
#    'Dermatology',
#    'Emergency Medicine',
#    'Endocrinology & Metabolism',
#    'Gastroenterology & Hepatology',
#    'Geriatrics & Gerontology',
#    'Gerontology',
#    'Hematology',
#    'Integrative & Complementary Medicine',
#    'Medicine, General & Internal',
#    'Obstetrics & Gynecology',
#    'Oncology',
#    'Ophthalmology',
#    'Orthopedics',
#    'Otorhinolaryngology',
#    'Pediatrics',
#    'Peripheral Vascular Disease',
#    'Psychiatry',
#    'Rehabilitation',
#    'Respiratory System',
#    'Rheumatology',
#    'Surgery',
#    'Transplantation',
#    'Tropical Medicine',
#    'Urology & Nephrology',
#    'Audiology & Speech-Language Pathology']],
#  ['Public Health',
#   ['Health Policy & Services',
#    'Health Care Sciences & Services',
#    'Infectious Diseases',
#    'Nutrition & Dietetics',
#    'Primary Health Care',
#    'Public, Environmental & Occupational Health',
#    'Social Sciences, Biomedical',
#    'Substance Abuse',
#    'Ergonomics']],
#  ['Dentistry & Oral Sciences', ['Dentistry, Oral Surgery & Medicine']],
#  ['Nursing', ['Nursing']],
#  ['Medical Technology',
#   ['Medical Laboratory Technology',
#    'Neuroimaging',
#    'Radiology, Nuclear Medicine & Medical Imaging']],
#  ['Pharmacy & Pharmaceutical Sciences',
#   ['Chemistry, Medicinal', 'Pharmacology & Pharmacy', 'Toxicology']],
#  ['Economics', ['Economics']],
#  ['Statistics', ['Statistics & Probability']],
#  ['Law', ['Criminology & Penology', 'Law']],
#  ['Political Sciences', ['International Relations', 'Political Science']],
#  ['Sociology', ['Sociology']],
#  ['Education',
#   ['Education & Educational Research',
#    'Education, Scientific Disciplines',
#    'Education, Special']],
#  ['Communication', ['Communication']],
#  ['Psychology',
#   ['Psychology',
#    'Psychology, Applied',
#    'Psychology, Biological',
#    'Psychology, Clinical',
#    'Psychology, Developmental',
#    'Psychology, Educational',
#    'Psychology, Experimental',
#    'Psychology, Mathematical',
#    'Psychology, Multidisciplinary',
#    'Psychology, Psychoanalysis',
#    'Psychology, Social',
#    'Behavioral Sciences']],
#  ['Business Administration', ['Business', 'Industrial Relations & Labor']],
#  ['Finance', ['Business, Finance']],
#  ['Management', ['Management', 'Operations Research & Management Science']],
#  ['Public Administration', ['Public Administration']],
#  ['Hospitality & Tourism Management',
#   ['Hospitality, Leisure, Sport & Tourism']],
#  ['Agricultural Economics', ['Agricultural Economics & Policy']],
#  ['Library & Information Science', ['Information Science & Library Science']]]
