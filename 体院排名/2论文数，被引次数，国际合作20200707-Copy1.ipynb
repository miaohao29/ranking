# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import csv
import time
import random

# %%
#读入csv中的数据，（导入检索式）
file_path = r'C:\Users\rk\Desktop\sport2020.csv'
with open(file_path) as f:
    csv_reader=csv.reader(f)
    a=list(csv_reader)
del a[0]#删除表头
c='AND DT=(Article OR Review)'
for lst in a:
    lst[3]=lst[3]+' '+c

# %%
a[:2]
# Out:
# [['L030-',
#   'Sport0001',
#   'Deakin University',
#   'AD=(Deakin Univ same (exercise or Phys Act) same Australia) AND DT=(Article OR Review)'],
#  ['L064-',
#   'Sport0002',
#   'Loughborough University',
#   'AD=((Loughborough Univ or Univ Loughborough) same sport* same England) AND DT=(Article OR Review)']]

# %%
a[1][3]
# Out:
# 'AD=((Loughborough Univ or Univ Loughborough) same sport* same England) AND DT=(Article OR Review)'

# %%
def delete(history_record):
    '''删除记录，满足history_record条即删掉除第一条之外的记录'''
    history_num = int(browser.find_element_by_class_name('historySetNum').text[2:])
    if history_num==history_record or history_num == history_record+1:#删除记录条数
        browser.find_element_by_xpath('/html/body/div[13]/form/table/tbody/tr[1]/th[6]/div[2]/button[1]').click()#全选
        time.sleep(0.3)
        browser.find_element_by_xpath("//input[@type='checkbox'and @name='dSet']").click()#取消第一个
        time.sleep(0.4)
        browser.find_element_by_xpath('/html/body/div[13]/form/table/tbody/tr[1]/th[6]/div[2]/button[2]/i').click()#删除
        time.sleep(0.5)

# %%
def search(item): 
    '''向搜索框里输入检索式'''
    browser.find_element_by_id('value(input1)').clear()#清除文本框里的内容
    browser.find_element_by_id('value(input1)').send_keys(item)#往文本框里输入搜索文本（输入检索式）
    time.sleep(0.5)
    try:
        browser.find_element_by_id('searchButton').click()#点击搜素按钮
    except:
        browser.find_element_by_id('search-button').click()#点击搜素按钮

# %%
def write_record(item):
    '''保存每次检索结果，防止程序崩溃，浏览器崩溃，服务器奔溃'''
    with open(r'C:\Users\rk\Desktop\Sport20200706-3.txt','a+') as file:
            string='、'.join(item)
            file.write(string+"\n")
            #print(item)

# %%
def click_all(inputs):
    '''点击所有复选框'''
    for i in inputs:
            if i.get_attribute('type')== 'checkbox':#点击所有复选框
                i.click()

# %%
def UKS(input1,input2):
    '''判断是否属于英国地区'''
    UK=('WALES','ENGLAND','SCOTLAND','NORTH IRELAND')#英国的四个地区
    flag=0
    get_txt=input2[0].text
    country=get_txt[:get_txt.find('(')]
    reg=country.strip()
    print(reg)
    for region in UK:#判断地区是否属于英国
        if region == reg:
            flag=1
            break   
    if flag==1:
        for i in range(0,len(input1)):
            get_txt=input2[i].text
            country=get_txt[:get_txt.find('(')]
            reg=country.strip() 
            for j in range(0,len(UK)):
                if reg==UK[j]:
                    input1[i].click()#如果属于则再次点击复选框，以取消选项
    else:input1[0].click()#再次点击第一个复选框

# %%
def restartBrowser():
    '''重启浏览器:但是，此函数会被服务器识别为爬虫，积极拒绝访问'''
    browser = webdriver.Chrome('C:/Users/rk/Desktop/chromedriver.exe') #锁定浏览器
    browser.get("http://apps.webofknowledge.com/WOS_AdvancedSearch_input.do?SID=8EJqZrebXFQVSmd9PsP&product=WOS&search_mode=AdvancedSearch")
    time.sleep(random.random()*2+2)
    browser.find_element_by_xpath('//*[@id="select2-databases-container"]').click()#点击数据库
    time.sleep(random.random()*2+2)
    browser.find_element_by_xpath('//*[@id="select2-databases-result-4rmn-/WOS_GeneralSearch_input.do?product=WOS&SID=8FKyF1e8yqxgvfL4ejn&search_mode=GeneralSearch"]').click()
    #选择数据库
    time.sleep(random.random()*2+2)
    browser.find_element_by_xpath('/html/body/div[9]/div/ul/li[4]/a').click()#点击高级检索
    time.sleep(random.random()*2+2)
    browser.find_element_by_xpath('//*[@id="timespan"]/div[2]/div/select/option[7]').click()#自定义年份
    time.sleep(random.random()*2+2)
    browser.find_element_by_xpath('//*[@id="timespan"]/div[3]/div/select[1]/option[30]').click()#2014年
    time.sleep(random.random()*2+2)
    browser.find_element_by_xpath('//*[@id="timespan"]/div[3]/div/select[2]/option[2]').click()#2018年
    time.sleep(random.random()*2+2)
    browser.find_element_by_xpath('//*[@id="WOS_AdvancedSearch_input_form"]/div[2]/div[2]/span').click()#更多设置
    time.sleep(random.random()*2+2)
    options=browser.find_elements_by_xpath('//*[@id="WOS_AdvancedSearch_input_form"]/div[2]/div[2]/div/div/div[1]/div//input')
    for option in options[2:]:
        time.sleep(random.random()*2+1)
        option.click()

# %%
count=0

# %%
########################服务器崩溃后，从此处运行##########################################
browser = webdriver.Chrome('C:/Users/rk/Desktop/chromedriver.exe') #锁定浏览器
######################此处与下面重复，但程序刚开始运行时，及服务器崩溃后需要重新运行###################
browser.get("http://apps.webofknowledge.com/WOS_AdvancedSearch_input.do?SID=8EJqZrebXFQVSmd9PsP&product=WOS&search_mode=AdvancedSearch")

# %%
#此处是程序运行(服务器拒绝访问，浏览器崩溃）等问题，无法进行，只能清除所有，重新启动后将count设置为之前的，接着运行，因为已经保存TXT，所以放心
count=0
#再三强调，不能随意执行这一步，除非程序重启

# %%
a[0]
# Out:
# ['L030-',
#  'Sport0001',
#  'Deakin University',
#  'AD=(Deakin Univ same (exercise or Phys Act) same Australia) AND DT=(Article or Review)']

# %%
'''文献类型容易跳到只有ARTICLE,所以需要检查是否准确'''

# %%
##########################程序中断后，从此处运行#####################################
#程序运行中，请勿点击页面，尤其是点击点击国际合作的时候，会导致程序异常终止
print(count)
for item in a[count:]:
    try:
        browser.find_element_by_xpath('//*[@id="skip-to-navigation"]/ul[1]/li/a').click()#点击检索
    except:
        pass
    try:
        delete(20)
    except:
        pass
    
    search(item[-1])#往文本框里输入搜索文本（输入检索式）
    
    d=browser.find_element_by_xpath('//*[@id="client_error_input_message"]').text#定位异常信息
    
    if len(d)==0:#判断检索式是否异常（如果正常运行，则不会弹出异常，那么异常信息len为零）
        v=browser.find_element_by_class_name('historyResults').text
             #如果没有异常，则定位第一个数据，因为每搜索一次，数据系列就增加一次，无法用ID定位，只能广泛定位，自动匹配第一个数据
        item.append(v)#将找到的数据拼接到原数据的后面
        articke_type=browser.find_element_by_xpath('/html/body/div[13]/form/table/tbody/tr[3]/td[3]/div[1]/span').text.replace("\n","")
        item.append(articke_type)
    else: 
        item.append('NA')#搜索异常的时候讲自定义的异常标识拼接到原数据后(相当于论文数)
        item.append('NA')#相当于检索式文献类型
        item.append('NA')#相当于被引次数
        item.append('NA')#相当于国际论文数
        write_record()
        count+=1
        print(count)
        continue
        
    #查询国际论文合作数会导致历史记录以公差为2递增，故前后设置了两次删除   
    delete(20)
        
    #获取除自引的被引频数
    browser.find_element_by_class_name('historyResults').click()  
    time.sleep(random.random()+1)
    browser.find_element_by_xpath('//*[@id="view_citation_report_image_placeholder"]/div/div').click()  
    time.sleep(random.random()+1)
    v1=browser.find_element_by_xpath('//*[@id="citation-report-display"]/table/tbody/tr[2]/td[3]/div/div[3]/em').text
    item.append(v1) 
    
    browser.back()#返回上一个页面
    time.sleep(random.random()+1)
    browser.find_element_by_xpath('//*[@id="refine_form"]/div[4]/a').click()#点击查看全部选项
    time.sleep(random.random()+1)
    d=browser.find_element_by_xpath('//*[@id="CountryTerritory_tr"]').text
    if len(d)==0:
        browser.find_element_by_xpath('//*[@id="CountryTerritory"]/h4').click()#如果国家地区没有展开，则点击国家地区
        time.sleep(random.random()+1)
    time.sleep(4)
    try:
        browser.find_element_by_xpath('//*[@id="CountryTerritory_tr"]/div[2]/a').click()#点击更多选项分类
        time.sleep(random.random()+1)
        inputs=browser.find_elements_by_xpath('//*[@id="CountryTerritory_raMore_tr"]/td/table/tbody//input')#查找所有复选项
        time.sleep(random.random()+1)
        
        click_all(inputs) #点击所有复选框
       
        inputs1=browser.find_elements_by_class_name('refineItem')
        
        UKS(inputs,inputs1)
        
        browser.find_element_by_xpath('//*[@id="raMore"]/table/tbody/tr[6]/td/table/tbody/tr/td[1]/div/button').click()#点击精炼
        time.sleep(random.random()+2)
        IC_number=browser.find_element_by_xpath('//*[@id="hitCount.top"]').text#提取国际合作论文数
        item.append(IC_number)
        #保存每条记录，浏览器，程序及服务器会崩溃，以防重新执行浪费时间
        write_record()
        count+=1
        print(count,'-',time.ctime(),'-',item[0])
        #time.sleep(0.5)
#         if count%40==0:#WOS有自己的判断机制，大约60条（约一小时）就会中断连接，所以此处没用
#             time.sleep(random.random()*2+5)
#             browser.quit()
#             print('it is time to sleep....')
#             time.sleep(random.random()*20+1800)#每40所学校，程序终止半小时，重启浏览器
#             restartBrowser()
    except:
        '''个别学校合作非常少，没有更多选项分类'''
        inputs2=browser.find_elements_by_xpath('//*[@id="CountryTerritory"]/div/div/div/div/input')#查找所有复选项
        if len(inputs2)==1:
            item.append("zero")
            write_record()
            count+=1
            print(count)
            continue
        else:
            click_all(inputs2)
        inputs3=browser.find_elements_by_xpath('//*[@id="CountryTerritory_raMore_tr"]/td/table/tbody//label')
        
        UKS(inputs2,inputs3)
        
        browser.find_element_by_xpath('//*[@id="CountryTerritory"]/div/div/button[1]').click()#点击精炼
        time.sleep(random.random()+2)
        IC_number=browser.find_element_by_xpath('//*[@id="hitCount.top"]').text#提取国际合作论文数
        item.append(IC_number) 
        write_record()
        count+=1
        print(count,'-',time.ctime(),'-',item[0])
        #time.sleep(0.5)
#         if count%40==0:
#             time.sleep(random.random()*2+5)
#             browser.quit()                                                                                                                                                                                                                                                                                                                                                                                                                               
#             print('it is time to sleep....')
#             time.sleep(random.random()*20+1800)#每40所学校，程序终止半小时，重启浏览器
#             restartBrowser()
# Out:
# 0
# AUSTRALIA
# 1 - Mon Jul  6 13:42:29 2020 - L030-
# ENGLAND
# 2 - Mon Jul  6 13:43:13 2020 - L064-
# USA
# 3 - Mon Jul  6 13:43:53 2020 - L231-
# NORWAY
# 4 - Mon Jul  6 13:44:36 2020 - L089-
# AUSTRALIA
# 5 - Mon Jul  6 13:45:19 2020 - L221-
# ENGLAND
# 6 - Mon Jul  6 13:46:05 2020 - L063-
# DENMARK
# 7 - Mon Jul  6 13:46:48 2020 - L234-
# BELGIUM
# 8 - Mon Jul  6 13:47:31 2020 - L056-
# BELGIUM
# 9 - Mon Jul  6 13:48:16 2020 - L166-
# GERMANY
# 10 - Mon Jul  6 13:49:00 2020 - L042-
# NETHERLANDS
# 11 - Mon Jul  6 13:49:50 2020 - L269-
# ENGLAND
# 12 - Mon Jul  6 13:50:36 2020 - L133-
# USA
# 13 - Mon Jul  6 13:51:16 2020 - L173-
# AUSTRALIA
# 14 - Mon Jul  6 13:52:13 2020 - L035-
# DENMARK
# 15 - Mon Jul  6 13:53:00 2020 - L150-
# CANADA
# 16 - Mon Jul  6 13:53:47 2020 - L136-
# AUSTRALIA
# 17 - Mon Jul  6 13:54:33 2020 - L260-
# CANADA
# 18 - Mon Jul  6 13:55:16 2020 - L070-
# AUSTRALIA
# 19 - Mon Jul  6 13:56:01 2020 - L268-
# ITALY
# 20 - Mon Jul  6 13:56:51 2020 - L253-
# CANADA
# 21 - Mon Jul  6 13:57:49 2020 - L273-
# BRAZIL
# 22 - Mon Jul  6 13:58:38 2020 - L227-
# PORTUGAL
# 23 - Mon Jul  6 13:59:42 2020 - L217-
# SPAIN
# 24 - Mon Jul  6 14:00:30 2020 - L267-
# NETHERLANDS
# 25 - Mon Jul  6 14:01:23 2020 - L066-
# CANADA
# 26 - Mon Jul  6 14:02:14 2020 - L126-
# NETHERLANDS
# 27 - Mon Jul  6 14:03:06 2020 - L170-
# USA
# 28 - Mon Jul  6 14:04:00 2020 - L163-
# NEW ZEALAND
# 29 - Mon Jul  6 14:04:59 2020 - L008-
# CANADA
# 30 - Mon Jul  6 14:05:52 2020 - L112-
# USA
# 31 - Mon Jul  6 14:06:54 2020 - L097-
# CANADA
# 32 - Mon Jul  6 14:07:42 2020 - L214-
# CANADA
# 33 - Mon Jul  6 14:08:31 2020 - L101-
# SPAIN
# 34 - Mon Jul  6 14:09:19 2020 - L169-
# USA
# 35 - Mon Jul  6 14:10:08 2020 - L244-
# CANADA
# 36 - Mon Jul  6 14:10:58 2020 - L258-
# ENGLAND
# 37 - Mon Jul  6 14:11:47 2020 - L157-
# BELGIUM
# 38 - Mon Jul  6 14:12:37 2020 - L270-
# USA
# 39 - Mon Jul  6 14:13:25 2020 - L257-
# FINLAND
# 40 - Mon Jul  6 14:14:21 2020 - L176-
# ENGLAND
# 41 - Mon Jul  6 14:15:20 2020 - L067-
# CANADA
# 42 - Mon Jul  6 14:16:10 2020 - L182-
# AUSTRALIA
# 43 - Mon Jul  6 14:17:03 2020 - L102-
# AUSTRALIA
# 44 - Mon Jul  6 14:17:48 2020 - L007-
# AUSTRALIA
# 45 - Mon Jul  6 14:18:39 2020 - L425-
# AUSTRALIA
# 46 - Mon Jul  6 14:19:26 2020 - L192-
# CANADA
# 47 - Mon Jul  6 14:20:12 2020 - L247-
# AUSTRALIA
# 48 - Mon Jul  6 14:21:01 2020 - L239-
# SOUTH AFRICA
# 49 - Mon Jul  6 14:21:56 2020 - L140-
# ENGLAND
# 50 - Mon Jul  6 14:22:41 2020 - L016-
# BRAZIL
# 51 - Mon Jul  6 14:23:41 2020 - L326-
# WALES
# 52 - Mon Jul  6 14:24:32 2020 - L010-
# CANADA
# 53 - Mon Jul  6 14:25:20 2020 - L261-
# SWITZERLAND
# 54 - Mon Jul  6 14:26:12 2020 - L128-
# ENGLAND
# 55 - Mon Jul  6 14:27:01 2020 - L100-
# IRELAND
# 56 - Mon Jul  6 14:27:52 2020 - L147-
# SWEDEN
# 57 - Mon Jul  6 14:28:36 2020 - L073-
# NORWAY
# 58 - Mon Jul  6 14:29:28 2020 - L090-
# USA
# 59 - Mon Jul  6 14:30:20 2020 - L215-
# CANADA
# 60 - Mon Jul  6 14:31:09 2020 - L138-
# AUSTRALIA
# 61 - Mon Jul  6 14:32:06 2020 - L043-
# WALES
# 62 - Mon Jul  6 14:32:59 2020 - L021-
# USA
# 63 - Mon Jul  6 14:33:59 2020 - L373-
# NEW ZEALAND
# 64 - Mon Jul  6 14:35:04 2020 - L213-
# ENGLAND
# 65 - Mon Jul  6 14:36:16 2020 - L317-
# WALES
# 66 - Mon Jul  6 14:37:22 2020 - L401-
# HUNGARY
# 67 - Mon Jul  6 14:38:30 2020 - L374-
# NORTH IRELAND
# 68 - Mon Jul  6 14:39:38 2020 - L249-
# USA
# 69 - Mon Jul  6 14:40:44 2020 - L233-
# SWITZERLAND
# 70 - Mon Jul  6 14:41:55 2020 - L181-
# USA
# 71 - Mon Jul  6 14:43:26 2020 - L033-
# GERMANY
# 72 - Mon Jul  6 14:44:36 2020 - L118-
# CANADA
# 73 - Mon Jul  6 14:45:48 2020 - L069-
# WALES
# 74 - Mon Jul  6 14:47:06 2020 - L115-
# ENGLAND
# 75 - Mon Jul  6 14:48:18 2020 - L370-
# USA
# 76 - Mon Jul  6 14:49:28 2020 - L195-
# NEW ZEALAND
# 77 - Mon Jul  6 14:50:47 2020 - L313-
# JAPAN
# 78 - Mon Jul  6 14:52:05 2020 - L271-
# USA
# 79 - Mon Jul  6 14:53:13 2020 - L120-
# SPAIN
# 80 - Mon Jul  6 14:54:27 2020 - L216-
# USA
# 81 - Mon Jul  6 14:55:48 2020 - L418-
# SCOTLAND
# 82 - Mon Jul  6 14:56:59 2020 - L237-
# PORTUGAL
# 83 - Mon Jul  6 14:58:00 2020 - L359-
# USA
# 84 - Mon Jul  6 14:59:08 2020 - L149-
# USA
# 85 - Mon Jul  6 15:00:14 2020 - L091-
# PORTUGAL
# 86 - Mon Jul  6 15:01:23 2020 - L146-
# NEW ZEALAND
# 87 - Mon Jul  6 15:02:39 2020 - L068-
# USA
# 88 - Mon Jul  6 15:03:45 2020 - L196-
# AUSTRALIA
# 89 - Mon Jul  6 15:04:54 2020 - L208-
# USA
# 90 - Mon Jul  6 15:05:59 2020 - L165-
# SWITZERLAND
# 91 - Mon Jul  6 15:07:29 2020 - L375-
# SCOTLAND
# 92 - Mon Jul  6 15:08:37 2020 - L259-
# PORTUGAL
# 93 - Mon Jul  6 15:09:42 2020 - L130-
# USA
# 94 - Mon Jul  6 15:10:45 2020 - L198-
# CANADA
# 95 - Mon Jul  6 15:11:56 2020 - L199-
# NORWAY
# 96 - Mon Jul  6 15:13:03 2020 - L124-
# SWEDEN
# 97 - Mon Jul  6 15:14:16 2020 - L116-
# FRANCE
# 98 - Mon Jul  6 15:15:24 2020 - L346-
# BRAZIL
# 99 - Mon Jul  6 15:16:38 2020 - L160-
# GERMANY
# 100 - Mon Jul  6 15:18:07 2020 - L376-
# PEOPLES R CHINA
# 101 - Mon Jul  6 15:19:40 2020 - L025-
# AUSTRALIA
# 102 - Mon Jul  6 15:20:52 2020 - L399-
# SWITZERLAND
# 103 - Mon Jul  6 15:22:01 2020 - L420-
# ENGLAND
# 104 - Mon Jul  6 15:23:18 2020 - L355-
# USA
# 105 - Mon Jul  6 15:24:34 2020 - L072-
# ENGLAND
# 106 - Mon Jul  6 15:25:45 2020 - L332-
# SWEDEN
# 107 - Mon Jul  6 15:27:15 2020 - L168-
# USA
# 108 - Mon Jul  6 15:28:31 2020 - L202-
# AUSTRIA
# 109 - Mon Jul  6 15:29:44 2020 - L106-
# AUSTRALIA
# 110 - Mon Jul  6 15:30:57 2020 - L077-
# USA
# 111 - Mon Jul  6 15:32:26 2020 - L305-
# PEOPLES R CHINA
# 112 - Mon Jul  6 15:33:38 2020 - L110-
# FRANCE
# 113 - Mon Jul  6 15:34:45 2020 - L349-
# USA
# 114 - Mon Jul  6 15:35:54 2020 - L190-
# USA
# 115 - Mon Jul  6 15:37:07 2020 - L038-
# BRAZIL
# 116 - Mon Jul  6 15:38:15 2020 - L422-
# SLOVENIA
# 117 - Mon Jul  6 15:39:20 2020 - L379-
# SINGAPORE
# 118 - Mon Jul  6 15:40:35 2020 - L079-
# FRANCE
# 119 - Mon Jul  6 15:41:29 2020 - L378-
# USA
# 120 - Mon Jul  6 15:42:19 2020 - L191-
# ENGLAND
# 121 - Mon Jul  6 15:43:22 2020 - L111-
# USA
# 122 - Mon Jul  6 15:44:11 2020 - L250-
# GREECE
# 123 - Mon Jul  6 15:45:07 2020 - L005-
# GREECE
# 124 - Mon Jul  6 15:48:21 2020 - L245-
# USA
# 125 - Mon Jul  6 15:49:17 2020 - L088-
# ENGLAND
# 126 - Mon Jul  6 15:50:13 2020 - L171-
# ENGLAND
# 127 - Mon Jul  6 15:51:10 2020 - L264-
# AUSTRALIA
# 128 - Mon Jul  6 15:52:03 2020 - L410-
# IRELAND
# 129 - Mon Jul  6 15:53:02 2020 - L184-
# USA
# 130 - Mon Jul  6 15:53:58 2020 - L047-
# ENGLAND
# 131 - Mon Jul  6 15:55:11 2020 - L087-
# CANADA
# 132 - Mon Jul  6 15:56:16 2020 - L071-
# USA
# 133 - Mon Jul  6 15:57:20 2020 - L151-
# USA
# 134 - Mon Jul  6 15:58:49 2020 - L212-
# USA
# 135 - Mon Jul  6 16:00:12 2020 - L276-
# SLOVENIA
# 136 - Mon Jul  6 16:02:46 2020 - L186-
# GERMANY
# 137 - Mon Jul  6 16:04:01 2020 - L225-
# USA
# 138 - Mon Jul  6 16:05:53 2020 - L423-
# SPAIN
# 139 - Mon Jul  6 16:06:51 2020 - L137-
# CROATIA
# 140 - Mon Jul  6 16:07:47 2020 - L266-
# PORTUGAL
# 141 - Mon Jul  6 16:08:48 2020 - L415-
# TAIWAN
# 142 - Mon Jul  6 16:09:51 2020 - L083-
# PEOPLES R CHINA
# 143 - Mon Jul  6 16:10:45 2020 - L122-
# CANADA
# 144 - Mon Jul  6 16:11:39 2020 - L228-
# SCOTLAND
# 145 - Mon Jul  6 16:12:32 2020 - L152-
# CZECH REPUBLIC
# 146 - Mon Jul  6 16:13:25 2020 - L095-
# USA
# 147 - Mon Jul  6 16:14:16 2020 - L053-
# ENGLAND
# 148 - Mon Jul  6 16:15:06 2020 - L153-
# DENMARK
# 149 - Mon Jul  6 16:15:56 2020 - L002-
# AUSTRALIA
# 150 - Mon Jul  6 16:16:45 2020 - L242-
# ENGLAND
# 151 - Mon Jul  6 16:17:44 2020 - L167-
# ENGLAND
# 152 - Mon Jul  6 16:18:35 2020 - L143-
# BRAZIL
# 153 - Mon Jul  6 16:19:22 2020 - L134-
# FRANCE
# 154 - Mon Jul  6 16:20:12 2020 - L404-
# GREECE
# 155 - Mon Jul  6 16:21:02 2020 - L127-
# AUSTRALIA
# 156 - Mon Jul  6 16:21:54 2020 - L238-
# USA
# 157 - Mon Jul  6 16:22:45 2020 - L381-
# FRANCE
# 158 - Mon Jul  6 16:23:35 2020 - L347-
# SPAIN
# 159 - Mon Jul  6 16:24:28 2020 - L352-
# GERMANY
# 160 - Mon Jul  6 16:25:21 2020 - L164-
# JAPAN
# 161 - Mon Jul  6 16:26:23 2020 - L248-
# ENGLAND
# 162 - Mon Jul  6 16:27:10 2020 - L113-
# ENGLAND
# 163 - Mon Jul  6 16:28:01 2020 - L178-
# SWITZERLAND
# 164 - Mon Jul  6 16:28:52 2020 - L132-
# TUNISIA
# 165 - Mon Jul  6 16:29:50 2020 - L299-
# BRAZIL
# 166 - Mon Jul  6 16:30:43 2020 - L380-
# ENGLAND
# 167 - Mon Jul  6 16:31:34 2020 - L093-
# ITALY
# 168 - Mon Jul  6 16:32:21 2020 - L411-
# CANADA
# 169 - Mon Jul  6 16:33:11 2020 - L015-
# NEW ZEALAND
# 170 - Mon Jul  6 16:34:00 2020 - L363-
# USA
# 171 - Mon Jul  6 16:35:00 2020 - L377-
# GERMANY
# 172 - Mon Jul  6 16:35:51 2020 - L104-
# USA
# 173 - Mon Jul  6 16:36:42 2020 - L369-
# PEOPLES R CHINA
# 174 - Mon Jul  6 16:37:37 2020 - L044-
# AUSTRALIA
# 175 - Mon Jul  6 16:38:28 2020 - L139-
# USA
# 176 - Mon Jul  6 16:39:21 2020 - L205-
# BRAZIL
# 177 - Mon Jul  6 16:40:14 2020 - L159-
# USA
# 178 - Mon Jul  6 16:41:05 2020 - L027-
# TAIWAN
# 179 - Mon Jul  6 16:42:01 2020 - L356-
# ITALY
# 180 - Mon Jul  6 16:42:51 2020 - L348-
# BRAZIL
# 181 - Mon Jul  6 16:43:50 2020 - L385-
# SPAIN
# 182 - Mon Jul  6 16:44:40 2020 - L180-
# FRANCE
# 183 - Mon Jul  6 16:45:33 2020 - L318-
# PEOPLES R CHINA
# 184 - Mon Jul  6 16:46:24 2020 - L388-
# AUSTRALIA
# 185 - Mon Jul  6 16:47:16 2020 - L023-
# SPAIN
# 186 - Mon Jul  6 16:48:07 2020 - L129-
# AUSTRALIA
# 187 - Mon Jul  6 16:49:05 2020 - L029-
# ENGLAND
# 188 - Mon Jul  6 16:49:56 2020 - L226-
# ENGLAND
# 189 - Mon Jul  6 16:50:54 2020 - L281-
# FRANCE
# 190 - Mon Jul  6 16:51:45 2020 - L341-
# GERMANY
# 191 - Mon Jul  6 16:52:47 2020 - L360-
# USA
# 192 - Mon Jul  6 16:53:40 2020 - L386-
# SPAIN
# 193 - Mon Jul  6 16:54:28 2020 - L141-
# GERMANY
# 194 - Mon Jul  6 16:55:23 2020 - L219-
# PORTUGAL
# 195 - Mon Jul  6 16:56:24 2020 - L185-
# CROATIA
# 196 - Mon Jul  6 16:57:39 2020 - L235-
# ENGLAND
# 197 - Mon Jul  6 16:58:47 2020 - L315-
# MALAYSIA
# 198 - Mon Jul  6 16:59:57 2020 - L340-
# ENGLAND
# 199 - Mon Jul  6 17:01:11 2020 - L358-
# AUSTRIA
# 200 - Mon Jul  6 17:02:20 2020 - L362-
# AUSTRIA
# 201 - Mon Jul  6 17:03:51 2020 - L174-
# BRAZIL
# 202 - Mon Jul  6 17:05:05 2020 - L155-
# BRAZIL
# 203 - Mon Jul  6 17:06:19 2020 - L345-
# USA
# 204 - Mon Jul  6 17:07:28 2020 - L243-
# ITALY
# 205 - Mon Jul  6 17:08:37 2020 - L224-
# GERMANY
# 206 - Mon Jul  6 17:09:49 2020 - L291-
# SERBIA
# 207 - Mon Jul  6 17:10:57 2020 - L131-
# ESTONIA
# 208 - Mon Jul  6 17:12:07 2020 - L241-
# SPAIN
# 209 - Mon Jul  6 17:13:06 2020 - L314-
# NEW ZEALAND
# 210 - Mon Jul  6 17:14:14 2020 - L298-
# SERBIA
# 211 - Mon Jul  6 17:15:40 2020 - L209-
# BRAZIL
# 212 - Mon Jul  6 17:16:45 2020 - L154-
# AUSTRALIA
# 213 - Mon Jul  6 17:17:54 2020 - L036-
# ENGLAND
# 214 - Mon Jul  6 17:19:00 2020 - L114-
# USA
# 215 - Mon Jul  6 17:20:09 2020 - L390-
# BRAZIL
# 216 - Mon Jul  6 17:21:11 2020 - L320-
# USA
# 217 - Mon Jul  6 17:22:15 2020 - L179-
# SPAIN
# 218 - Mon Jul  6 17:23:23 2020 - L251-
# ENGLAND
# 219 - Mon Jul  6 17:24:37 2020 - L218-
# GERMANY
# 220 - Mon Jul  6 17:25:44 2020 - L392-
# CANADA
# 221 - Mon Jul  6 17:27:07 2020 - L254-
# SOUTH KOREA
# 222 - Mon Jul  6 17:28:15 2020 - L109-
# SWEDEN
# 223 - Mon Jul  6 17:29:22 2020 - L055-
# LITHUANIA
# 224 - Mon Jul  6 17:30:32 2020 - L062-
# PEOPLES R CHINA
# 225 - Mon Jul  6 17:31:37 2020 - L011-
# ENGLAND
# 226 - Mon Jul  6 17:32:46 2020 - L061-
# USA
# 227 - Mon Jul  6 17:33:49 2020 - L105-
# AUSTRALIA
# 228 - Mon Jul  6 17:34:56 2020 - L049-
# USA
# 229 - Mon Jul  6 17:36:03 2020 - L046-
# PORTUGAL
# 230 - Mon Jul  6 17:37:10 2020 - L321-
# SPAIN
# 231 - Mon Jul  6 17:38:32 2020 - L094-
# USA
# 232 - Mon Jul  6 17:39:35 2020 - L026-
# ENGLAND
# 233 - Mon Jul  6 17:40:40 2020 - L034-
# USA
# 234 - Mon Jul  6 17:41:29 2020 - L019-
# USA
# 235 - Mon Jul  6 17:42:18 2020 - L017-
# ENGLAND
# 236 - Mon Jul  6 17:43:06 2020 - L144-
# NEW ZEALAND
# 237 - Mon Jul  6 17:43:53 2020 - L416-
# SPAIN
# 238 - Mon Jul  6 17:44:41 2020 - L312-
# JAPAN
# 239 - Mon Jul  6 17:45:38 2020 - L052-
# JAPAN
# 240 - Mon Jul  6 17:46:32 2020 - L103-
# USA
# 241 - Mon Jul  6 17:47:32 2020 - L412-
# GERMANY
# 242 - Mon Jul  6 17:48:22 2020 - L402-
# USA
# 243 - Mon Jul  6 17:49:10 2020 - L413-
# GERMANY
# 244 - Mon Jul  6 17:49:55 2020 - L403-
# SPAIN
# 245 - Mon Jul  6 17:50:51 2020 - L158-
# GREECE
# 246 - Mon Jul  6 17:51:37 2020 - L031-
# USA
# 247 - Mon Jul  6 17:52:26 2020 - L098-
# ENGLAND
# 248 - Mon Jul  6 17:53:17 2020 - L135-
# USA
# 249 - Mon Jul  6 17:54:11 2020 - L006-
# USA
# 250 - Mon Jul  6 17:55:03 2020 - L004-
# USA
# 251 - Mon Jul  6 17:56:03 2020 - L065-
# USA
# 252 - Mon Jul  6 17:56:52 2020 - L117-
# SPAIN
# 253 - Mon Jul  6 17:57:39 2020 - L255-
# BRAZIL
# 254 - Mon Jul  6 17:58:32 2020 - L161-
# POLAND
# 255 - Mon Jul  6 17:59:21 2020 - L040-
# JAPAN
# 256 - Mon Jul  6 18:00:08 2020 - L081-
# SPAIN
# 257 - Mon Jul  6 18:00:57 2020 - L075-
# USA
# 258 - Mon Jul  6 18:01:43 2020 - L207-
# GERMANY
# 259 - Mon Jul  6 18:02:33 2020 - L287-
# POLAND
# 260 - Mon Jul  6 18:03:21 2020 - L240-
# USA
# 261 - Mon Jul  6 18:04:25 2020 - L125-
# ENGLAND
# 262 - Mon Jul  6 18:05:20 2020 - L123-
# ENGLAND
# 263 - Mon Jul  6 18:06:09 2020 - L316-
# SPAIN
# 264 - Mon Jul  6 18:06:59 2020 - L338-
# USA
# 265 - Mon Jul  6 18:07:48 2020 - L197-
# TURKEY
# 266 - Mon Jul  6 18:08:36 2020 - L395-
# JAPAN
# 267 - Mon Jul  6 18:09:21 2020 - L293-
# ENGLAND
# 268 - Mon Jul  6 18:10:08 2020 - L145-
# USA
# 269 - Mon Jul  6 18:10:56 2020 - L391-
# BRAZIL
# 270 - Mon Jul  6 18:11:41 2020 - L424-
# USA
# 271 - Mon Jul  6 18:12:37 2020 - L393-
# POLAND
# 272 - Mon Jul  6 18:13:29 2020 - L050-
# CANADA
# 273 - Mon Jul  6 18:14:19 2020 - L272-
# BRAZIL
# 274 - Mon Jul  6 18:15:08 2020 - L323-
# NORWAY
# 275 - Mon Jul  6 18:15:58 2020 - L308-
# POLAND
# 276 - Mon Jul  6 18:16:49 2020 - L051-
# CANADA
# 277 - Mon Jul  6 18:17:38 2020 - L060-
# USA
# 278 - Mon Jul  6 18:18:24 2020 - L193-
# USA
# 279 - Mon Jul  6 18:19:14 2020 - L282-
# USA
# 280 - Mon Jul  6 18:20:02 2020 - L387-
# USA
# 281 - Mon Jul  6 18:21:00 2020 - L142-
# USA
# 282 - Mon Jul  6 18:21:48 2020 - L119-
# TAIWAN
# 283 - Mon Jul  6 18:22:38 2020 - L080-
# GERMANY
# 284 - Mon Jul  6 18:23:25 2020 - L200-
# SWEDEN
# 285 - Mon Jul  6 18:24:14 2020 - L289-
# CANADA
# 286 - Mon Jul  6 18:25:03 2020 - L222-
# JAPAN
# 287 - Mon Jul  6 18:25:52 2020 - L400-
# ENGLAND
# 288 - Mon Jul  6 18:26:38 2020 - L074-
# CANADA
# 289 - Mon Jul  6 18:27:27 2020 - L183-
# TAIWAN
# 290 - Mon Jul  6 18:28:14 2020 - L082-
# CANADA
# 291 - Mon Jul  6 18:29:12 2020 - L354-
# CANADA
# 292 - Mon Jul  6 18:30:00 2020 - L262-
# ENGLAND
# 293 - Mon Jul  6 18:30:49 2020 - L303-
# CZECH REPUBLIC
# 294 - Mon Jul  6 18:31:38 2020 - L024-
# PEOPLES R CHINA
# 295 - Mon Jul  6 18:32:27 2020 - L096-
# GERMANY
# 296 - Mon Jul  6 18:33:15 2020 - L295-
# JAPAN
# 297 - Mon Jul  6 18:34:03 2020 - L085-
# CANADA
# 298 - Mon Jul  6 18:35:09 2020 - L189-
# SOUTH AFRICA
# 299 - Mon Jul  6 18:36:20 2020 - L220-
# USA
# 300 - Mon Jul  6 18:37:27 2020 - L256-
# USA
# 301 - Mon Jul  6 18:38:49 2020 - L351-
# 302
# USA
# 303 - Mon Jul  6 18:40:40 2020 - L076-
# SPAIN
# 304 - Mon Jul  6 18:41:48 2020 - L201-
# POLAND
# 305 - Mon Jul  6 18:42:56 2020 - L230-
# JAPAN
# 306 - Mon Jul  6 18:44:01 2020 - L039-
# PEOPLES R CHINA
# 307 - Mon Jul  6 18:45:09 2020 - L389-
# USA
# 308 - Mon Jul  6 18:46:14 2020 - L223-
# USA
# 309 - Mon Jul  6 18:47:20 2020 - L405-
# GERMANY
# 310 - Mon Jul  6 18:48:27 2020 - L398-
# USA
# 311 - Mon Jul  6 18:50:16 2020 - L204-
# BRAZIL
# 312 - Mon Jul  6 18:51:43 2020 - L162-
# BRAZIL
# 313 - Mon Jul  6 18:52:56 2020 - L307-
# USA
# 314 - Mon Jul  6 18:54:00 2020 - L285-
# USA
# 315 - Mon Jul  6 18:55:10 2020 - L092-
# ISRAEL
# 316 - Mon Jul  6 18:56:11 2020 - L310-
# USA
# 317 - Mon Jul  6 18:57:18 2020 - L265-
# USA
# 318 - Mon Jul  6 18:58:27 2020 - L045-
# USA
# 319 - Mon Jul  6 18:59:40 2020 - L286-
# USA
# 320 - Mon Jul  6 19:00:47 2020 - L309-
# BRAZIL
# 321 - Mon Jul  6 19:02:14 2020 - L156-
# JAPAN
# 322 - Mon Jul  6 19:03:20 2020 - L394-
# USA
# 323 - Mon Jul  6 19:04:29 2020 - L014-
# USA
# 324 - Mon Jul  6 19:05:31 2020 - L421-
# USA
# 325 - Mon Jul  6 19:06:38 2020 - L188-
# USA
# 326 - Mon Jul  6 19:07:46 2020 - L246-
# USA
# 327 - Mon Jul  6 19:08:51 2020 - L366-
# USA
# 328 - Mon Jul  6 19:09:55 2020 - L121-
# USA
# 329 - Mon Jul  6 19:11:02 2020 - L407-
# USA
# 330 - Mon Jul  6 19:12:07 2020 - L210-
# USA
# 331 - Mon Jul  6 19:13:36 2020 - L296-
# IRAN
# 332 - Mon Jul  6 19:14:42 2020 - L048-
# BRAZIL
# 333 - Mon Jul  6 19:15:48 2020 - L322-
# USA
# 334 - Mon Jul  6 19:16:50 2020 - L041-
# USA
# 335 - Mon Jul  6 19:18:00 2020 - L263-
# USA
# 336 - Mon Jul  6 19:19:05 2020 - L396-
# USA
# 337 - Mon Jul  6 19:20:20 2020 - L028-
# USA
# 338 - Mon Jul  6 19:21:21 2020 - L277-
# USA
# 339 - Mon Jul  6 19:22:29 2020 - L274-
# USA
# 340 - Mon Jul  6 19:23:37 2020 - L177-
# IRAN
# 341 - Mon Jul  6 19:25:05 2020 - L397-
# SOUTH KOREA
# 342 - Mon Jul  6 19:26:11 2020 - L371-
# SPAIN
# 343 - Mon Jul  6 19:27:19 2020 - L020-
# USA
# 344 - Mon Jul  6 19:28:27 2020 - L417-
# USA
# 345 - Mon Jul  6 19:29:35 2020 - L172-
# POLAND
# 346 - Mon Jul  6 19:30:43 2020 - L229-
# USA
# 347 - Mon Jul  6 19:31:50 2020 - L419-
# IRAN
# 348 - Mon Jul  6 19:32:54 2020 - L333-
# USA
# 349 - Mon Jul  6 19:33:59 2020 - L408-
# USA
# 350 - Mon Jul  6 19:35:09 2020 - L009-
# USA
# 351 - Mon Jul  6 19:36:36 2020 - L383-
# BRAZIL
# 352 - Mon Jul  6 19:37:42 2020 - L331-
# USA
# 353 - Mon Jul  6 19:38:48 2020 - L368-
# POLAND
# 354 - Mon Jul  6 19:39:53 2020 - L372-
# USA
# 355 - Mon Jul  6 19:40:52 2020 - L409-
# USA
# 356 - Mon Jul  6 19:41:39 2020 - L426-
# TURKEY
# 357 - Mon Jul  6 19:42:27 2020 - L283-
# USA
# 358 - Mon Jul  6 19:43:15 2020 - L194-
# QATAR
# 359 - Mon Jul  6 19:44:04 2020 - L099-
# SPAIN
# 360 - Mon Jul  6 19:44:55 2020 - L278-
# AUSTRALIA
# 361 - Mon Jul  6 19:46:00 2020 - L350-
# SERBIA
# 362 - Mon Jul  6 19:46:52 2020 - L211-
# TAIWAN
# 363 - Mon Jul  6 19:47:36 2020 - L414-
# PORTUGAL
# 364 - Mon Jul  6 19:48:25 2020 - L406-
# SPAIN
# 365 - Mon Jul  6 19:49:18 2020 - L284-
# SWITZERLAND
# 366 - Mon Jul  6 19:50:07 2020 - L382-
# AUSTRIA
# 367 - Mon Jul  6 19:50:56 2020 - L288-
# FRANCE
# 368 - Mon Jul  6 19:51:45 2020 - L203-
# ENGLAND
# 369 - Mon Jul  6 19:52:33 2020 - L384-
# PEOPLES R CHINA
# 370 - Mon Jul  6 19:53:20 2020 - L428-
# PEOPLES R CHINA
# 371 - Mon Jul  6 19:54:16 2020 - L429-
# DENMARK
# 372 - Mon Jul  6 19:55:04 2020 - L001-
# SCOTLAND
# 373 - Mon Jul  6 19:55:54 2020 - L003-
# AUSTRALIA
# 374 - Mon Jul  6 19:56:43 2020 - L012-
# ENGLAND
# 375 - Mon Jul  6 19:57:32 2020 - L013-
# USA
# 376 - Mon Jul  6 19:58:18 2020 - L018-
# AUSTRALIA
# 377 - Mon Jul  6 19:59:04 2020 - L022-
# JAPAN
# 378 - Mon Jul  6 19:59:53 2020 - L032-
# USA
# 379 - Mon Jul  6 20:00:40 2020 - L037-
# TAIWAN
# 380 - Mon Jul  6 20:01:25 2020 - L054-
# USA
# 381 - Mon Jul  6 20:02:21 2020 - L057-
# SOUTH KOREA
# 382 - Mon Jul  6 20:03:40 2020 - L058-
# AUSTRALIA
# 383 - Mon Jul  6 20:04:30 2020 - L059-
# JAPAN
# 384 - Mon Jul  6 20:05:22 2020 - L078-
# JAPAN
# 385 - Mon Jul  6 20:06:09 2020 - L084-
# USA
# 386 - Mon Jul  6 20:07:04 2020 - L086-
# USA
# 387 - Mon Jul  6 20:07:52 2020 - L107-
# BRAZIL
# 388 - Mon Jul  6 20:08:43 2020 - L108-
# USA
# 389 - Mon Jul  6 20:09:32 2020 - L148-
# SOUTH AFRICA
# 390 - Mon Jul  6 20:10:19 2020 - L175-
# CHILE
# 391 - Mon Jul  6 20:11:17 2020 - L187-
# CANADA
# 392 - Mon Jul  6 20:12:08 2020 - L206-
# WALES
# 393 - Mon Jul  6 20:12:56 2020 - L232-
# SOUTH AFRICA
# 394 - Mon Jul  6 20:13:53 2020 - L236-
# USA
# 395 - Mon Jul  6 20:14:41 2020 - L252-
# ENGLAND
# 396 - Mon Jul  6 20:15:58 2020 - L275-
# JAPAN
# 397 - Mon Jul  6 20:16:48 2020 - L279-
# SLOVAKIA
# 398 - Mon Jul  6 20:17:43 2020 - L280-
# NETHERLANDS
# 399 - Mon Jul  6 20:18:35 2020 - L290-
# USA
# 400 - Mon Jul  6 20:19:31 2020 - L292-
# GERMANY
# 401 - Mon Jul  6 20:20:31 2020 - L294-
# SOUTH KOREA
# 402 - Mon Jul  6 20:21:24 2020 - L297-
# USA
# 403 - Mon Jul  6 20:22:12 2020 - L300-
# USA
# 404 - Mon Jul  6 20:23:01 2020 - L301-
# SOUTH AFRICA
# 405 - Mon Jul  6 20:23:55 2020 - L302-
# USA
# 406 - Mon Jul  6 20:24:48 2020 - L304-
# USA
# 407 - Mon Jul  6 20:25:37 2020 - L306-
# USA
# 408 - Mon Jul  6 20:26:31 2020 - L311-
# ENGLAND
# 409 - Mon Jul  6 20:27:21 2020 - L319-
# BRAZIL
# 410 - Mon Jul  6 20:28:48 2020 - L324-
# BRAZIL
# 411 - Mon Jul  6 20:29:49 2020 - L325-
# BRAZIL
# 412 - Mon Jul  6 20:30:41 2020 - L327-
# BRAZIL
# 413 - Mon Jul  6 20:31:27 2020 - L328-
# BRAZIL
# 414 - Mon Jul  6 20:32:16 2020 - L329-
# BRAZIL
# 415 - Mon Jul  6 20:33:03 2020 - L330-
# GERMANY
# 416 - Mon Jul  6 20:34:02 2020 - L334-
# TUNISIA
# 417 - Mon Jul  6 20:34:51 2020 - L335-
# SOUTH AFRICA
# 418 - Mon Jul  6 20:36:14 2020 - L336-
# CHILE
# 419 - Mon Jul  6 20:37:06 2020 - L337-
# FRANCE
# 420 - Mon Jul  6 20:38:13 2020 - L339-
# USA
# 421 - Mon Jul  6 20:39:38 2020 - L342-
# USA
# 422 - Mon Jul  6 20:41:04 2020 - L343-
# ITALY
# 423 - Mon Jul  6 20:42:19 2020 - L344-
# TUNISIA
# 424 - Mon Jul  6 20:43:27 2020 - L353-
# AUSTRALIA
# 425 - Mon Jul  6 20:44:31 2020 - L357-
# ITALY
# 426 - Mon Jul  6 20:45:45 2020 - L361-
# ENGLAND
# 427 - Mon Jul  6 20:46:54 2020 - L364-
# GERMANY
# 428 - Mon Jul  6 20:48:04 2020 - L365-
# USA
# 429 - Mon Jul  6 20:49:09 2020 - L367-

# %%
count=30
count
# Out:
# 30
